# %% [markdown]
# # Movie Recommendation System using Genre Embeddings and Vector DB

# %% [markdown]
# #### This Colab notebook aims to illustrate the process of creating a recommendation system using genre embeddings developed through a Neural Network and a Vector DB. For a deeper understanding, refer to this [paper](https://arxiv.org/pdf/2309.08787), and to understand the whole story, refer to my [blog](https://colab.research.google.com/drive/1B6I5SEXzuuEVaHcy4IwaJlrMy8wJfPSx?usp=sharing).

# %% [markdown]
# ### Genre Spectrum Embeddings
#
# The Genre Spectrum approach involves combining the various movie genres or characteristics of a movie to form Initial embeddings, which offer a comprehensive portrayal of the movie content. Then these embeddings are used as a input to train a Deep Learning model producing `Genre Spectrum embeddings` at the penultimate layer.
#
# These embeddings serve dual purposes: they can either be directly inputted into a classification model for genre classification or stored in a VectorDB. By storing embeddings in a VectorDB, efficient retrieval and query search for recommendations become possible at a later stage. This architecture offers a holistic understanding of the underlying processes involved.

# %% [markdown]
# ### Installing the relevant dependencies

# %%
# !pip install torch scikit-learn lancedb nltk gensim lancedb scipy==1.12 kaggle
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.2.1+cu121)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.2.2)
# Collecting lancedb
#   Downloading lancedb-0.6.13-cp38-abi3-manylinux_2_28_x86_64.whl (18.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.9/18.9 MB 35.3 MB/s eta 0:00:00
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: gensim in /usr/local/lib/python3.10/dist-packages (4.3.2)
# Collecting scipy==1.12
#   Downloading scipy-1.12.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (38.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.4/38.4 MB 13.6 MB/s eta 0:00:00
# Requirement already satisfied: kaggle in /usr/local/lib/python3.10/dist-packages (1.6.12)
# Requirement already satisfied: numpy<1.29.0,>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from scipy==1.12) (1.25.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.14.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.11.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.19.3 (from torch)
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch) (2.2.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch)
#   Using cached nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.5.0)
# Collecting deprecation (from lancedb)
#   Downloading deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Collecting pylance==0.10.12 (from lancedb)
#   Downloading pylance-0.10.12-cp38-abi3-manylinux_2_28_x86_64.whl (22.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.4/22.4 MB 53.3 MB/s eta 0:00:00
# Collecting ratelimiter~=1.0 (from lancedb)
#   Downloading ratelimiter-1.2.0.post0-py3-none-any.whl (6.6 kB)
# Requirement already satisfied: requests>=2.31.0 in /usr/local/lib/python3.10/dist-packages (from lancedb) (2.31.0)
# Collecting retry>=0.9.2 (from lancedb)
#   Downloading retry-0.9.2-py2.py3-none-any.whl (8.0 kB)
# Requirement already satisfied: tqdm>=4.27.0 in /usr/local/lib/python3.10/dist-packages (from lancedb) (4.66.4)
# Requirement already satisfied: pydantic>=1.10 in /usr/local/lib/python3.10/dist-packages (from lancedb) (2.7.1)
# Requirement already satisfied: attrs>=21.3.0 in /usr/local/lib/python3.10/dist-packages (from lancedb) (23.2.0)
# Collecting semver (from lancedb)
#   Downloading semver-3.0.2-py3-none-any.whl (17 kB)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.10/dist-packages (from lancedb) (5.3.3)
# Collecting overrides>=0.7 (from lancedb)
#   Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Requirement already satisfied: pyarrow<15.0.1,>=12 in /usr/local/lib/python3.10/dist-packages (from pylance==0.10.12->lancedb) (14.0.2)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2023.12.25)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from gensim) (6.4.0)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.10/dist-packages (from kaggle) (1.16.0)
# Requirement already satisfied: certifi>=2023.7.22 in /usr/local/lib/python3.10/dist-packages (from kaggle) (2024.2.2)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.10/dist-packages (from kaggle) (8.0.4)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.0.7)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from kaggle) (6.1.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.10->lancedb) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.2 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.10->lancedb) (2.18.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31.0->lancedb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31.0->lancedb) (3.7)
# Requirement already satisfied: decorator>=3.4.2 in /usr/local/lib/python3.10/dist-packages (from retry>=0.9.2->lancedb) (4.4.2)
# Collecting py<2.0.0,>=1.4.26 (from retry>=0.9.2->lancedb)
#   Downloading py-1.11.0-py2.py3-none-any.whl (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 kB 11.4 MB/s eta 0:00:00
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from deprecation->lancedb) (24.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.10/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# Installing collected packages: ratelimiter, semver, scipy, py, overrides, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, deprecation, retry, pylance, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, lancedb
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.11.4
#     Uninstalling scipy-1.11.4:
#       Successfully uninstalled scipy-1.11.4
# Successfully installed deprecation-2.1.0 lancedb-0.6.13 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.1.105 overrides-7.7.0 py-1.11.0 pylance-0.10.12 ratelimiter-1.2.0.post0 retry-0.9.2 scipy-1.12.0 semver-3.0.2

# %% [markdown]
# ## Kaggle Configuration and Data Needs
#
# We are using a movies metadata data which is being uploaded on the Kaggle. To download the dataset and use it for our recommendation system, we will need a `kaggle.json` file containing our creds.
#
# You can download the `kaggle.json` file from your Kaggle account settings. Follow these steps and make your life easy.
#
# 1. Go to Kaggle and log in to your account.
# 2. Navigate to Your Account Settings and click on your profile picture in the top right corner of the page, Now From the dropdown menu, select `Account`.
# 3. Scroll down to the `API` section, Click on `Create New API Token`. This will download a file named kaggle.json to your computer.
#
# Once you have the `kaggle.json` file, you need to upload it here on colab data space. After uploading the `kaggle.json` file, run the following code to set up the credentials and download the dataset in `data` directory

# %%
import json
import os

# Assuming kaggle.json is uploaded to the current directory
with open('kaggle.json') as f:
    kaggle_credentials = json.load(f)

os.environ['KAGGLE_USERNAME'] = kaggle_credentials['username']
os.environ['KAGGLE_KEY'] = kaggle_credentials['key']

# %%
from kaggle.api.kaggle_api_extended import KaggleApi

# Initialize the Kaggle API
api = KaggleApi()
api.authenticate()

# Specify the dataset you want to download
dataset = 'rounakbanik/the-movies-dataset'
destination = 'data/'

# Create the destination directory if it doesn't exist
if not os.path.exists(destination):
    os.makedirs(destination)

# Download the dataset
api.dataset_download_files(dataset, path=destination, unzip=True)

print(f"Dataset {dataset} downloaded to {destination}")
# Out:
# Dataset URL: https://www.kaggle.com/datasets/rounakbanik/the-movies-dataset
# Dataset rounakbanik/the-movies-dataset downloaded to data/

# %% [markdown]
# ### Training a `Doc2Vec` model and building the Vocab

# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from nltk import word_tokenize
from torch.utils.data import DataLoader, TensorDataset
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import train_test_split
from tqdm import tqdm

import nltk
nltk.download('punkt')

# Read data from CSV file
movie_data = pd.read_csv('data/movies_metadata.csv', low_memory=False)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

def preprocess_data(movie_data_chunk):
    tagged_docs = []
    valid_indices = []
    movie_info = []

    # Wrap your loop with tqdm
    for i, row in tqdm(movie_data_chunk.iterrows(), total=len(movie_data_chunk)):
        try:
            # Constructing movie text
            movies_text = ''
            genres = ', '.join([genre['name'] for genre in eval(row['genres'])])
            movies_text += "Genres: " + genres + '\n'
            movies_text += "Title: " + row['title'] + '\n'
            tagged_docs.append(TaggedDocument(words=word_tokenize(movies_text.lower()), tags=[str(i)]))
            valid_indices.append(i)
            movie_info.append((row['title'], genres))
        except Exception as e:
            continue

    return tagged_docs, valid_indices, movie_info

def train_doc2vec_model(tagged_data, num_epochs=10):
    # Initialize Doc2Vec model
    doc2vec_model = Doc2Vec(vector_size=100, min_count=2, epochs=num_epochs)
    doc2vec_model.build_vocab(tqdm(tagged_data, desc="Building Vocabulary"))
    for epoch in range(num_epochs):
        doc2vec_model.train(tqdm(tagged_data, desc=f"Epoch {epoch+1}"), total_examples=doc2vec_model.corpus_count, epochs=doc2vec_model.epochs)

    return doc2vec_model

# Preprocess data and extract genres for the first 1000 movies
chunk_size = 1000
tagged_data = []
valid_indices = []
movie_info = []
for chunk_start in range(0, len(movie_data), chunk_size):
    movie_data_chunk = movie_data.iloc[chunk_start:chunk_start+chunk_size]
    chunk_tagged_data, chunk_valid_indices, chunk_movie_info = preprocess_data(movie_data_chunk)
    tagged_data.extend(chunk_tagged_data)
    valid_indices.extend(chunk_valid_indices)
    movie_info.extend(chunk_movie_info)

doc2vec_model = train_doc2vec_model(tagged_data)
doc2vec_model.save("doc2vec_model")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 100%|██████████| 1000/1000 [00:00<00:00, 1027.42it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 1507.88it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 2878.24it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 3182.71it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 3356.53it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 3107.71it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 3288.81it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 3119.84it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 3029.96it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 3116.96it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 3361.77it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 2930.60it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 2366.91it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 2956.92it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 3042.90it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 3050.06it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 3195.25it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 3129.35it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 3328.62it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 3426.27it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 3178.31it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 3313.43it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 3430.04it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 3329.66it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 3081.24it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 3353.40it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 3064.09it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 3189.51it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 3363.69it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 3452.84it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 1312.59it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 2485.33it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 2028.87it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 888.74it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 899.69it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 641.08it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 659.35it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 558.48it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 635.68it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 725.27it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 1167.07it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 1367.30it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 1434.73it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 1573.16it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 1156.91it/s]
# 100%|██████████| 466/466 [00:00<00:00, 1653.79it/s]
# Building Vocabulary: 100%|██████████| 45460/45460 [00:00<00:00, 96593.60it/s]
# Epoch 1: 100%|██████████| 45460/45460 [00:03<00:00, 12147.80it/s]
# Epoch 2:   0%|          | 0/45460 [00:00<?, ?it/s]WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# Epoch 2: 100%|██████████| 45460/45460 [00:02<00:00, 16478.54it/s]
# Epoch 3:   0%|          | 0/45460 [00:00<?, ?it/s]WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# Epoch 3: 100%|██████████| 45460/45460 [00:03<00:00, 14806.74it/s]
# Epoch 4:   0%|          | 0/45460 [00:00<?, ?it/s]WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# Epoch 4: 100%|██████████| 45460/45460 [00:03<00:00, 11936.90it/s]
# Epoch 5:   0%|          | 0/45460 [00:00<?, ?it/s]WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# Epoch 5: 100%|██████████| 45460/45460 [00:03<00:00, 15084.11it/s]
# Epoch 6:   0%|          | 0/45460 [00:00<?, ?it/s]WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# Epoch 6: 100%|██████████| 45460/45460 [00:02<00:00, 15931.08it/s]
# Epoch 7:   0%|          | 0/45460 [00:00<?, ?it/s]WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# Epoch 7: 100%|██████████| 45460/45460 [00:02<00:00, 15780.21it/s]
# Epoch 8:   0%|          | 0/45460 [00:00<?, ?it/s]WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# Epoch 8: 100%|██████████| 45460/45460 [00:02<00:00, 16107.10it/s]
# Epoch 9:   0%|          | 0/45460 [00:00<?, ?it/s]WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# Epoch 9: 100%|██████████| 45460/45460 [00:03<00:00, 14174.55it/s]
# Epoch 10:   0%|          | 0/45460 [00:00<?, ?it/s]WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# Epoch 10: 100%|██████████| 45460/45460 [00:02<00:00, 15663.02it/s]

# %% [markdown]
# ### Training a Neural Network to Predict the Genres for a given Movie!

# %%
# Extract genre labels for the valid indices
genres_list = []
for i in valid_indices:
    row = movie_data.loc[i]
    genres = [genre['name'] for genre in eval(row['genres'])]
    genres_list.append(genres)

mlb = MultiLabelBinarizer()
genre_labels = mlb.fit_transform(genres_list)

embeddings = []
for i in valid_indices:
    embeddings.append(doc2vec_model.dv[str(i)])
X_train, X_test, y_train, y_test = train_test_split(embeddings, genre_labels, test_size=0.2, random_state=42)

X_train_np = np.array(X_train, dtype=np.float32)
y_train_np = np.array(y_train, dtype=np.float32)
X_test_np = np.array(X_test, dtype=np.float32)
y_test_np = np.array(y_test, dtype=np.float32)

X_train_tensor = torch.tensor(X_train_np)
y_train_tensor = torch.tensor(y_train_np)
X_test_tensor = torch.tensor(X_test_np)
y_test_tensor = torch.tensor(y_test_np)

class GenreClassifier(nn.Module):
    def __init__(self, input_size, output_size):
        super(GenreClassifier, self).__init__()
        self.fc1 = nn.Linear(input_size, 512)
        self.bn1 = nn.BatchNorm1d(512)
        self.fc2 = nn.Linear(512, 256)
        self.bn2 = nn.BatchNorm1d(256)
        self.fc3 = nn.Linear(256, 128)
        self.bn3 = nn.BatchNorm1d(128)
        self.fc4 = nn.Linear(128, output_size)
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(p=0.2)  # Adjust the dropout rate as needed

    def forward(self, x):
        x = self.fc1(x)
        x = self.bn1(x)
        x = self.relu(x)
        x = self.dropout(x)
        x = self.fc2(x)
        x = self.bn2(x)
        x = self.relu(x)
        x = self.dropout(x)
        x = self.fc3(x)
        x = self.bn3(x)
        x = self.relu(x)
        x = self.dropout(x)
        x = self.fc4(x)
        return x

# Move model to the selected device
model = GenreClassifier(input_size=100, output_size=len(mlb.classes_)).to(device)

# Define loss function and optimizer
criterion = nn.BCEWithLogitsLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Training loop
epochs = 50
batch_size = 64

train_dataset = TensorDataset(X_train_tensor.to(device), y_train_tensor.to(device))
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

for epoch in range(epochs):
    model.train()
    running_loss = 0.0
    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)  # Move data to device
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item() * inputs.size(0)
    epoch_loss = running_loss / len(train_loader.dataset)
    print(f'Epoch [{epoch + 1}/{epochs}], Loss: {epoch_loss:.4f}')
# Out:
# Epoch [1/50], Loss: 0.1100
# Epoch [2/50], Loss: 0.0473
# Epoch [3/50], Loss: 0.0396
# Epoch [4/50], Loss: 0.0352
# Epoch [5/50], Loss: 0.0326
# Epoch [6/50], Loss: 0.0308
# Epoch [7/50], Loss: 0.0293
# Epoch [8/50], Loss: 0.0278
# Epoch [9/50], Loss: 0.0266
# Epoch [10/50], Loss: 0.0256
# Epoch [11/50], Loss: 0.0253
# Epoch [12/50], Loss: 0.0245
# Epoch [13/50], Loss: 0.0232
# Epoch [14/50], Loss: 0.0229
# Epoch [15/50], Loss: 0.0227
# Epoch [16/50], Loss: 0.0222
# Epoch [17/50], Loss: 0.0213
# Epoch [18/50], Loss: 0.0212
# Epoch [19/50], Loss: 0.0203
# Epoch [20/50], Loss: 0.0197
# Epoch [21/50], Loss: 0.0193
# Epoch [22/50], Loss: 0.0199
# Epoch [23/50], Loss: 0.0188
# Epoch [24/50], Loss: 0.0184
# Epoch [25/50], Loss: 0.0182
# Epoch [26/50], Loss: 0.0183
# Epoch [27/50], Loss: 0.0175
# Epoch [28/50], Loss: 0.0172
# Epoch [29/50], Loss: 0.0169
# Epoch [30/50], Loss: 0.0169
# Epoch [31/50], Loss: 0.0168
# Epoch [32/50], Loss: 0.0165
# Epoch [33/50], Loss: 0.0163
# Epoch [34/50], Loss: 0.0160
# Epoch [35/50], Loss: 0.0160
# Epoch [36/50], Loss: 0.0158
# Epoch [37/50], Loss: 0.0154
# Epoch [38/50], Loss: 0.0156
# Epoch [39/50], Loss: 0.0150
# Epoch [40/50], Loss: 0.0148
# Epoch [41/50], Loss: 0.0150
# Epoch [42/50], Loss: 0.0143
# Epoch [43/50], Loss: 0.0143
# Epoch [44/50], Loss: 0.0146
# Epoch [45/50], Loss: 0.0143
# Epoch [46/50], Loss: 0.0143
# Epoch [47/50], Loss: 0.0140
# Epoch [48/50], Loss: 0.0138
# Epoch [49/50], Loss: 0.0140
# Epoch [50/50], Loss: 0.0139

# %% [markdown]
# ### Testing the `model` to see if our model is able to predict the genres for the movies from the test dataset

# %%
from sklearn.metrics import f1_score

model.eval()
with torch.no_grad():
    X_test_tensor, y_test_tensor = X_test_tensor.to(device), y_test_tensor.to(device)  # Move test data to device
    outputs = model(X_test_tensor)
    test_loss = criterion(outputs, y_test_tensor)
    print(f'Test Loss: {test_loss.item():.4f}')


thresholds = [0.1] * len(mlb.classes_)
thresholds_tensor = torch.tensor(thresholds, device=device).unsqueeze(0)

# Convert the outputs to binary predictions using varying thresholds
predicted_labels = (outputs > thresholds_tensor).cpu().numpy()

# Convert binary predictions and actual labels to multi-label format
predicted_multilabels = mlb.inverse_transform(predicted_labels)
actual_multilabels = mlb.inverse_transform(y_test_np)

# Print the Predicted and Actual Labels for each movie
for i, (predicted, actual) in enumerate(zip(predicted_multilabels, actual_multilabels)):
    print(f'Movie {i+1}:')
    print(f'    Predicted Labels: {predicted}')
    print(f'    Actual Labels: {actual}')


# Compute F1-score
f1 = f1_score(y_test_np, predicted_labels, average='micro')
print(f'F1-score: {f1:.4f}')

# Saving the trained model
torch.save(model.state_dict(), 'trained_model.pth')
# Out:
# Streaming output truncated to the last 5000 lines.
#     Actual Labels: ('Comedy', 'Romance')
# Movie 7427:
#     Predicted Labels: ('Romance',)
#     Actual Labels: ('Romance', 'TV Movie')
# Movie 7428:
#     Predicted Labels: ('Comedy', 'Romance')
#     Actual Labels: ('Comedy', 'Romance')
# Movie 7429:
#     Predicted Labels: ('Comedy', 'Drama')
#     Actual Labels: ('Comedy', 'Drama')
# Movie 7430:
#     Predicted Labels: ('Action', 'Crime', 'Drama', 'Thriller')
#     Actual Labels: ('Action', 'Crime', 'Drama', 'Thriller')
# Movie 7431:
#     Predicted Labels: ('Comedy',)
#     Actual Labels: ('Comedy',)
# Movie 7432:
#     Predicted Labels: ('Action', 'Comedy', 'Crime')
#     Actual Labels: ('Action', 'Comedy', 'Crime')
# Movie 7433:
#     Predicted Labels: ()
#     Actual Labels: ('Comedy',)
# Movie 7434:
#     Predicted Labels: ('Horror',)
#     Actual Labels: ('Horror',)
# Movie 7435:
#     Predicted Labels: ('Comedy',)
#     Actual Labels: ('Comedy',)
# Movie 7436:
#     Predicted Labels: ('Drama', 'Fantasy')
#     Actual Labels: ('Drama', 'Fantasy')
# Movie 7437:
#     Predicted Labels: ('Comedy', 'Family', 'Science Fiction')
#     Actual Labels: ('Comedy', 'Family', 'Science Fiction')
# Movie 7438:
#     Predicted Labels: ('Comedy', 'Drama', 'Family')
#     Actual Labels: ('Comedy', 'Family')
# Movie 7439:
#     Predicted Labels: ('Action', 'Crime', 'Thriller')
#     Actual Labels: ('Action', 'Crime', 'Thriller')
# Movie 7440:
#     Predicted Labels: ('Horror', 'Thriller')
#     Actual Labels: ('Horror', 'Thriller')
# Movie 7441:
#     Predicted Labels: ('Comedy',)
#     Actual Labels: ('Comedy',)
# Movie 7442:
#     Predicted Labels: ('Drama', 'History', 'War')
#     Actual Labels: ('Drama', 'History', 'War')
# Movie 7443:
#     Predicted Labels: ('Animation', 'Comedy', 'Family')
#     Actual Labels: ('Animation', 'Comedy', 'Family')
# Movie 7444:
#     Predicted Labels: ('Crime', 'Drama', 'Mystery', 'Thriller')
#     Actual Labels: ('Crime', 'Drama', 'Mystery', 'Thriller')
# Movie 7445:
#     Predicted Labels: ('Action', 'Crime', 'Drama', 'Foreign')
#     Actual Labels: ('Action', 'Crime', 'Drama', 'Foreign')
# Movie 7446:
#     Predicted Labels: ('Documentary',)
#     Actual Labels: ('Documentary',)
# Movie 7447:
#     Predicted Labels: ('Comedy', 'Family', 'Romance', 'Science Fiction')
#     Actual Labels: ('Comedy', 'Family', 'Romance', 'Science Fiction')
# Movie 7448:
#     Predicted Labels: ('Drama', 'Horror', 'Mystery', 'Thriller')
#     Actual Labels: ('Drama', 'Horror', 'Mystery', 'Thriller')
# Movie 7449:
#     Predicted Labels: ('Drama', 'TV Movie')
#     Actual Labels: ('Drama', 'TV Movie')
# Movie 7450:
#     Predicted Labels: ('Action', 'Thriller')
#     Actual Labels: ('Action', 'Thriller')
# Movie 7451:
#     Predicted Labels: ('Drama', 'Romance')
#     Actual Labels: ('Drama', 'Romance')
# Movie 7452:
#     Predicted Labels: ('Comedy',)
#     Actual Labels: ('Comedy',)
# Movie 7453:
#     Predicted Labels: ('Comedy', 'Horror', 'Romance')
#     Actual Labels: ('Comedy', 'Horror', 'Romance')
# Movie 7454:
#     Predicted Labels: ()
#     Actual Labels: ()
# Movie 7455:
#     Predicted Labels: ('Drama',)
#     Actual Labels: ('Drama',)
# Movie 7456:
#     Predicted Labels: ('Documentary',)
#     Actual Labels: ('Documentary',)
# Movie 7457:
#     Predicted Labels: ('Comedy', 'Horror')
#     Actual Labels: ('Comedy', 'Horror')
# Movie 7458:
#     Predicted Labels: ('Drama',)
#     Actual Labels: ('Drama',)
# Movie 7459:
#     Predicted Labels: ('Comedy', 'Crime')
#     Actual Labels: ('Comedy', 'Crime')
# Movie 7460:
#     Predicted Labels: ('Drama', 'Music', 'Romance')
#     Actual Labels: ('Drama', 'Music', 'Romance')
# Movie 7461:
#     Predicted Labels: ('Action', 'Foreign')
#     Actual Labels: ('Action', 'Foreign')
# Movie 7462:
#     Predicted Labels: ('Drama',)
#     Actual Labels: ('Drama',)
# Movie 7463:
#     Predicted Labels: ('Comedy', 'Family', 'Fantasy')
#     Actual Labels: ('Family', 'Fantasy', 'Romance')
# Movie 7464:
#     Predicted Labels: ('Comedy',)
#     Actual Labels: ('Comedy',)
# Movie 7465:
#     Predicted Labels: ('Horror', 'Thriller')
#     Actual Labels: ('Horror', 'Thriller')
# Movie 7466:
#     Predicted Labels: ('Drama', 'Romance')
#     Actual Labels: ('Drama', 'Romance')
# Movie 7467:
#     Predicted Labels: ('Crime', 'Drama')
#     Actual Labels: ('Crime', 'Drama')
# Movie 7468:
#     Predicted Labels: ('Comedy', 'Drama', 'Romance')
#     Actual Labels: ('Comedy', 'Romance')
# Movie 7469:
#     Predicted Labels: ('Crime', 'Drama')
#     Actual Labels: ('Crime',)
# Movie 7470:
#     Predicted Labels: ('Action', 'Western')
#     Actual Labels: ('Western',)
# Movie 7471:
#     Predicted Labels: ('Comedy', 'Drama', 'Romance')
#     Actual Labels: ('Comedy', 'Drama', 'Romance')
# Movie 7472:
#     Predicted Labels: ('Drama', 'TV Movie')
#     Actual Labels: ('Drama', 'TV Movie')
# Movie 7473:
#     Predicted Labels: ('Action', 'Adventure', 'Drama', 'Western')
#     Actual Labels: ('Action', 'Adventure', 'Drama', 'Western')
# Movie 7474:
#     Predicted Labels: ('Crime', 'Mystery')
#     Actual Labels: ('Crime', 'Mystery')
# Movie 7475:
#     Predicted Labels: ('Drama', 'History', 'Romance')
#     Actual Labels: ('Drama', 'History', 'Romance')
# Movie 7476:
#     Predicted Labels: ('Horror', 'Thriller')
#     Actual Labels: ('Horror', 'Thriller')
# Movie 7477:
#     Predicted Labels: ('Family', 'Fantasy', 'TV Movie')
#     Actual Labels: ('Family', 'Fantasy', 'TV Movie')
# Movie 7478:
#     Predicted Labels: ('Drama', 'Romance')
#     Actual Labels: ('Comedy', 'Drama', 'Romance')
# Movie 7479:
#     Predicted Labels: ('Drama', 'Family', 'War')
#     Actual Labels: ('Comedy', 'Drama', 'Family', 'War')
# Movie 7480:
#     Predicted Labels: ('Action', 'Crime', 'Drama')
#     Actual Labels: ('Action', 'Crime', 'Drama')
# Movie 7481:
#     Predicted Labels: ()
#     Actual Labels: ()
# Movie 7482:
#     Predicted Labels: ('Comedy', 'Drama')
#     Actual Labels: ('Comedy', 'Drama')
# Movie 7483:
#     Predicted Labels: ('Action',)
#     Actual Labels: ('Action',)
# Movie 7484:
#     Predicted Labels: ('Crime', 'Drama')
#     Actual Labels: ('Crime', 'Drama')
# Movie 7485:
#     Predicted Labels: ('Documentary', 'History')
#     Actual Labels: ('Documentary', 'History')
# Movie 7486:
#     Predicted Labels: ('Music', 'Romance')
#     Actual Labels: ('Music', 'Romance')
# Movie 7487:
#     Predicted Labels: ('Drama', 'Thriller')
#     Actual Labels: ('Drama', 'Thriller')
# Movie 7488:
#     Predicted Labels: ('Action', 'Drama', 'History', 'Thriller')
#     Actual Labels: ('Action', 'Drama', 'History', 'Thriller')
# Movie 7489:
#     Predicted Labels: ('Crime', 'Thriller')
#     Actual Labels: ('Crime', 'Thriller')
# Movie 7490:
#     Predicted Labels: ('Action', 'Adventure', 'Fantasy')
#     Actual Labels: ('Action', 'Adventure', 'Fantasy')
# Movie 7491:
#     Predicted Labels: ('Comedy', 'Science Fiction')
#     Actual Labels: ('Comedy', 'Science Fiction')
# Movie 7492:
#     Predicted Labels: ('Comedy', 'Drama')
#     Actual Labels: ('Comedy', 'Drama')
# Movie 7493:
#     Predicted Labels: ('Action', 'Adventure', 'Fantasy')
#     Actual Labels: ('Action', 'Adventure', 'Fantasy', 'TV Movie')
# Movie 7494:
#     Predicted Labels: ('Horror', 'Thriller')
#     Actual Labels: ('Horror', 'Thriller')
# Movie 7495:
#     Predicted Labels: ()
#     Actual Labels: ()
# Movie 7496:
#     Predicted Labels: ('Adventure', 'Western')
#     Actual Labels: ('Adventure', 'Drama', 'Western')
# Movie 7497:
#     Predicted Labels: ('Drama', 'Thriller')
#     Actual Labels: ('Drama', 'Thriller')
# Movie 7498:
#     Predicted Labels: ('Drama', 'Mystery', 'Thriller')
#     Actual Labels: ('Drama', 'Mystery', 'Thriller')
# Movie 7499:
#     Predicted Labels: ('Drama', 'War')
#     Actual Labels: ('Drama', 'War')
# Movie 7500:
#     Predicted Labels: ('Drama', 'Horror', 'Science Fiction', 'Thriller')
#     Actual Labels: ('Drama', 'Horror', 'Science Fiction', 'Thriller')
# Movie 7501:
#     Predicted Labels: ('Comedy', 'Drama')
#     Actual Labels: ('Comedy', 'Drama')
# Movie 7502:
#     Predicted Labels: ('Adventure', 'Comedy', 'Fantasy')
#     Actual Labels: ('Adventure', 'Comedy', 'Fantasy')
# Movie 7503:
#     Predicted Labels: ('Thriller',)
#     Actual Labels: ('Thriller',)
# Movie 7504:
#     Predicted Labels: ('Drama', 'Mystery')
#     Actual Labels: ('Drama', 'Mystery')
# Movie 7505:
#     Predicted Labels: ('Comedy', 'Romance')
#     Actual Labels: ('Comedy', 'Drama', 'Romance')
# Movie 7506:
#     Predicted Labels: ('Drama', 'History', 'War')
#     Actual Labels: ('Drama', 'History', 'War')
# Movie 7507:
#     Predicted Labels: ('Drama', 'Fantasy', 'Mystery', 'Thriller')
#     Actual Labels: ('Drama', 'Fantasy', 'Mystery', 'Thriller')
# Movie 7508:
#     Predicted Labels: ('Action', 'Adventure')
#     Actual Labels: ('Action', 'Adventure')
# Movie 7509:
#     Predicted Labels: ('Crime', 'Foreign', 'Mystery', 'Thriller')
#     Actual Labels: ('Crime', 'Foreign', 'Mystery', 'Thriller')
# Movie 7510:
#     Predicted Labels: ('Action', 'Comedy', 'Crime', 'Music')
#     Actual Labels: ('Action', 'Comedy', 'Crime', 'Music')
# Movie 7511:
#     Predicted Labels: ('Action', 'Crime', 'Drama')
#     Actual Labels: ('Action', 'Crime', 'Drama')
# Movie 7512:
#     Predicted Labels: ('Drama', 'Romance')
#     Actual Labels: ('Drama', 'Romance')
# Movie 7513:
#     Predicted Labels: ('Drama',)
#     Actual Labels: ('Drama',)
# Movie 7514:
#     Predicted Labels: ('Action', 'Adventure', 'Comedy', 'Family', 'Science Fiction')
#     Actual Labels: ('Action', 'Adventure', 'Comedy', 'Family', 'Science Fiction')
# Movie 7515:
#     Predicted Labels: ('Comedy',)
#     Actual Labels: ('Comedy',)
# Movie 7516:
#     Predicted Labels: ('Horror',)
#     Actual Labels: ('Horror',)
# Movie 7517:
#     Predicted Labels: ('Comedy', 'Drama')
#     Actual Labels: ('Comedy', 'Drama')
# Movie 7518:
#     Predicted Labels: ('Documentary',)
#     Actual Labels: ('Documentary',)
# Movie 7519:
#     Predicted Labels: ('Documentary',)
#     Actual Labels: ('Documentary',)
# Movie 7520:
#     Predicted Labels: ('Action', 'Adventure', 'Science Fiction')
#     Actual Labels: ('Action', 'Adventure', 'Fantasy', 'Science Fiction')
# Movie 7521:
#     Predicted Labels: ('Drama',)
#     Actual Labels: ('Drama',)
# Movie 7522:
#     Predicted Labels: ('Drama', 'War')
#     Actual Labels: ('Drama', 'War')
# Movie 7523:
#     Predicted Labels: ('Action', 'Comedy', 'Horror')
#     Actual Labels: ('Action', 'Comedy', 'Horror')
# Movie 7524:
#     Predicted Labels: ('Comedy', 'Romance')
#     Actual Labels: ('Comedy', 'Romance')
# Movie 7525:
#     Predicted Labels: ('Drama',)
#     Actual Labels: ('Drama',)
# Movie 7526:
#     Predicted Labels: ('Drama', 'Romance')
#     Actual Labels: ('Drama', 'Romance')
# Movie 7527:
#     Predicted Labels: ('Crime', 'Drama')
#     Actual Labels: ('Crime', 'Drama')
# Movie 7528:
#     Predicted Labels: ('Drama',)
#     Actual Labels: ('Drama',)
# Movie 7529:
#     Predicted Labels: ('Drama',)
#     Actual Labels: ('Drama',)
# Movie 7530:
#     Predicted Labels: ('Action', 'Science Fiction', 'Thriller')
#     Actual Labels: ('Action', 'Science Fiction', 'Thriller', 'War')
# Movie 7531:
#     Predicted Labels: ('Comedy', 'Thriller')
#     Actual Labels: ('Comedy', 'Thriller')
# Movie 7532:
#     Predicted Labels: ('Horror', 'Thriller')
#     Actual Labels: ('Horror', 'Thriller')
# Movie 7533:
#     Predicted Labels: ('Comedy',)
#     Actual Labels: ('Comedy',)
# Movie 7534:
#     Predicted Labels: ('Documentary',)
#     Actual Labels: ('Documentary',)
# Movie 7535:
#     Predicted Labels: ('Action', 'Adventure', 'Drama', 'Family')
#     Actual Labels: ('Action', 'Drama', 'Family')
# Movie 7536:
#     Predicted Labels: ('Documentary',)
#     Actual Labels: ('Documentary',)
# Movie 7537:
#     Predicted Labels: ('Drama', 'Romance', 'Thriller')
#     Actual Labels: ('Drama', 'Romance', 'Thriller')
# Movie 7538:
#     Predicted Labels: ('Action', 'Adventure')
#     Actual Labels: ('Action', 'Adventure')
# Movie 7539:
#     Predicted Labels: ('Drama', 'War')
#     Actual Labels: ('Drama',)
# Movie 7540:
#     Predicted Labels: ('Comedy', 'Horror')
#     Actual Labels: ('Comedy', 'Horror')
# Movie 7541:
#     Predicted Labels: ('Animation', 'History')
#     Actual Labels: ('Animation', 'History')
# Movie 7542:
#     Predicted Labels: ('Action', 'Drama', 'Thriller')
#     Actual Labels: ('Action', 'Drama', 'Thriller')
# Movie 7543:
#     Predicted Labels: ('Drama', 'Mystery', 'Thriller')
#     Actual Labels: ('Drama', 'Mystery', 'Thriller')
# Movie 7544:
#     Predicted Labels: ('Comedy', 'Drama')
#     Actual Labels: ('Comedy', 'Drama')
# Movie 7545:
#     Predicted Labels: ('Science Fiction', 'Thriller')
#     Actual Labels: ('Science Fiction', 'Thriller')
# Movie 7546:
#     Predicted Labels: ('Comedy', 'Foreign')
#     Actual Labels: ('Comedy', 'Foreign', 'Horror')
# Movie 7547:
#     Predicted Labels: ('Action', 'Adventure', 'Thriller')
#     Actual Labels: ('Action', 'Adventure', 'Thriller')
# Movie 7548:
#     Predicted Labels: ('Action', 'Drama', 'Horror', 'Science Fiction', 'Thriller')
#     Actual Labels: ('Action', 'Drama', 'Horror', 'Science Fiction', 'Thriller')
# Movie 7549:
#     Predicted Labels: ('War',)
#     Actual Labels: ('War',)
# Movie 7550:
#     Predicted Labels: ('Comedy', 'Drama', 'Family')
#     Actual Labels: ('Comedy', 'Drama')
# Movie 7551:
#     Predicted Labels: ('Comedy', 'Horror')
#     Actual Labels: ('Comedy', 'Horror')
# Movie 7552:
#     Predicted Labels: ('Comedy', 'Drama', 'Romance')
#     Actual Labels: ('Comedy', 'Drama', 'Romance')
# Movie 7553:
#     Predicted Labels: ('Action', 'History', 'War')
#     Actual Labels: ('Action', 'History', 'War')
# Movie 7554:
#     Predicted Labels: ('Comedy',)
#     Actual Labels: ('Comedy',)
# Movie 7555:
#     Predicted Labels: ('Comedy',)
#     Actual Labels: ('Comedy',)
# Movie 7556:
#     Predicted Labels: ('Drama', 'Thriller')
#     Actual Labels: ('Drama', 'Thriller')
# Movie 7557:
#     Predicted Labels: ('Comedy',)
#     Actual Labels: ('Comedy',)
# Movie 7558:
#     Predicted Labels: ('Drama',)
#     Actual Labels: ('Drama',)
# Movie 7559:
#     Predicted Labels: ('Comedy', 'Foreign')
#     Actual Labels: ('Comedy', 'Foreign')
# Movie 7560:
#     Predicted Labels: ('Action', 'Science Fiction', 'Thriller')
#     Actual Labels: ('Action', 'Science Fiction', 'Thriller')
# Movie 7561:
#     Predicted Labels: ('Comedy',)
#     Actual Labels: ()
# Movie 7562:
#     Predicted Labels: ('Comedy',)
#     Actual Labels: ('Comedy',)
# Movie 7563:
#     Predicted Labels: ('Documentary',)
#     Actual Labels: ('Documentary',)
# Movie 7564:
#     Predicted Labels: ('Action', 'Adventure', 'Comedy', 'Drama')
#     Actual Labels: ('Action', 'Adventure', 'Comedy', 'Drama')
# Movie 7565:
#     Predicted Labels: ('Horror', 'Science Fiction', 'Thriller')
#     Actual Labels: ('Horror', 'Science Fiction', 'Thriller')
# Movie 7566:
#     Predicted Labels: ('Comedy', 'Romance')
#     Actual Labels: ('Comedy', 'Romance')
# Movie 7567:
#     Predicted Labels: ()
#     Actual Labels: ('Comedy',)
# Movie 7568:
#     Predicted Labels: ('Comedy', 'Drama', 'Romance')
#     Actual Labels: ('Comedy', 'Drama', 'Romance')
# Movie 7569:
#     Predicted Labels: ('Comedy', 'Romance')
#     Actual Labels: ('Comedy', 'Romance')
# Movie 7570:
#     Predicted Labels: ('Documentary',)
#     Actual Labels: ('Documentary',)
# Movie 7571:
#     Predicted Labels: ()
#     Actual Labels: ()
# Movie 7572:
#     Predicted Labels: ('Comedy',)
#     Actual Labels: ('Comedy',)
# Movie 7573:
#     Predicted Labels: ('Comedy', 'Drama', 'Science Fiction')
#     Actual Labels: ('Comedy', 'Drama', 'Science Fiction')
# Movie 7574:
#     Predicted Labels: ('Action', 'Drama', 'Foreign', 'Romance', 'Thriller')
#     Actual Labels: ('Action', 'Drama', 'Foreign', 'Romance', 'Thriller')
# Movie 7575:
#     Predicted Labels: ('War',)
#     Actual Labels: ('War',)
# Movie 7576:
#     Predicted Labels: ('War', 'Western')
#     Actual Labels: ('War', 'Western')
# Movie 7577:
#     Predicted Labels: ('Action', 'Horror', 'Science Fiction', 'Thriller')
#     Actual Labels: ('Action', 'Horror', 'Science Fiction', 'Thriller')
# Movie 7578:
#     Predicted Labels: ('Adventure', 'Drama', 'Family')
#     Actual Labels: ('Adventure', 'Drama', 'Family')
# Movie 7579:
#     Predicted Labels: ('Horror',)
#     Actual Labels: ('Comedy', 'Horror')
# Movie 7580:
#     Predicted Labels: ('Crime', 'Drama')
#     Actual Labels: ('Crime', 'Drama')
# Movie 7581:
#     Predicted Labels: ('Action', 'Drama')
#     Actual Labels: ('Action', 'Drama', 'Thriller')
# Movie 7582:
#     Predicted Labels: ('Comedy', 'Romance')
#     Actual Labels: ('Comedy', 'Romance')
# Movie 7583:
#     Predicted Labels: ('Comedy', 'Drama')
#     Actual Labels: ('Comedy', 'Drama')
# Movie 7584:
#     Predicted Labels: ('Animation', 'Fantasy', 'Horror')
#     Actual Labels: ('Animation', 'Fantasy', 'Horror')
# Movie 7585:
#     Predicted Labels: ('Action', 'Thriller')
#     Actual Labels: ('Action', 'Thriller')
# Movie 7586:
#     Predicted Labels: ('Horror', 'Science Fiction')
#     Actual Labels: ('Horror', 'Science Fiction')
# Movie 7587:
#     Predicted Labels: ('Comedy',)
#     Actual Labels: ('Comedy',)
# Movie 7588:
#     Predicted Labels: ('Animation',)
#     Actual Labels: ('Animation',)
# Movie 7589:
#     Predicted Labels: ('Drama',)
#     Actual Labels: ('Drama',)
# Movie 7590:
#     Predicted Labels: ('Documentary',)
#     Actual Labels: ('Documentary',)
# Movie 7591:
#     Predicted Labels: ('History', 'Thriller')
#     Actual Labels: ('Drama', 'History', 'Thriller')
# Movie 7592:
#     Predicted Labels: ('Action', 'Drama')
#     Actual Labels: ('Action', 'Drama', 'Thriller')
# Movie 7593:
#     Predicted Labels: ('Action',)
#     Actual Labels: ('Action',)
# Movie 7594:
#     Predicted Labels: ('Action', 'Drama')
#     Actual Labels: ('Action', 'Drama')
# Movie 7595:
#     Predicted Labels: ('Drama',)
#     Actual Labels: ('Drama',)
# Movie 7596:
#     Predicted Labels: ('Documentary', 'Music')
#     Actual Labels: ('Documentary',)
# Movie 7597:
#     Predicted Labels: ('Crime', 'Thriller')
#     Actual Labels: ('Crime', 'Drama', 'Thriller')
# Movie 7598:
#     Predicted Labels: ('Action',)
#     Actual Labels: ('Action',)
# Movie 7599:
#     Predicted Labels: ('Horror',)
#     Actual Labels: ('Horror',)
# Movie 7600:
#     Predicted Labels: ()
#     Actual Labels: ()
# Movie 7601:
#     Predicted Labels: ('Mystery', 'Thriller')
#     Actual Labels: ('Mystery', 'Thriller')
# Movie 7602:
#     Predicted Labels: ('Comedy', 'Drama')
#     Actual Labels: ('Comedy', 'Drama', 'Romance')
# Movie 7603:
#     Predicted Labels: ()
#     Actual Labels: ()
# Movie 7604:
#     Predicted Labels: ('Action', 'Adventure', 'Fantasy')
#     Actual Labels: ('Action', 'Adventure', 'Fantasy')
# Movie 7605:
#     Predicted Labels: ('Horror', 'Thriller')
#     Actual Labels: ('Horror', 'Thriller')
# Movie 7606:
#     Predicted Labels: ('Horror', 'Thriller')
#     Actual Labels: ('Horror', 'Thriller')
# Movie 7607:
#     Predicted Labels: ()
#     Actual Labels: ()
# Movie 7608:
#     Predicted Labels: ('Drama', 'Music', 'Romance')
#     Actual Labels: ('Drama', 'Music', 'Romance')
# Movie 7609:
#     Predicted Labels: ('Horror',)
#     Actual Labels: ('Horror',)
# Movie 7610:
#     Predicted Labels: ('Family', 'Fantasy')
#     Actual Labels: ('Family', 'Fantasy')
# Movie 7611:
#     Predicted Labels: ('Horror',)
#     Actual Labels: ('Horror',)
# Movie 7612:
#     Predicted Labels: ('Comedy', 'Crime', 'Drama')
#     Actual Labels: ('Comedy', 'Crime', 'Drama')
# Movie 7613:
#     Predicted Labels: ('Action', 'Adventure', 'Drama')
#     Actual Labels: ('Action', 'Adventure', 'Drama')
# Movie 7614:
#     Predicted Labels: ('Animation',)
#     Actual Labels: ('Animation', 'Fantasy')
# Movie 7615:
#     Predicted Labels: ('Drama',)
#     Actual Labels: ('Drama',)
# Movie 7616:
#     Predicted Labels: ('Comedy',)
#     Actual Labels: ('Comedy',)
# Movie 7617:
#     Predicted Labels: ('Comedy', 'Mystery', 'Thriller')
#     Actual Labels: ('Comedy', 'Mystery', 'Thriller')
# Movie 7618:
#     Predicted Labels: ('Documentary',)
#     Actual Labels: ('Documentary',)
# Movie 7619:
#     Predicted Labels: ('Documentary',)
#     Actual Labels: ('Documentary',)
# Movie 7620:
#     Predicted Labels: ('Horror',)
#     Actual Labels: ('Horror',)
# Movie 7621:
#     Predicted Labels: ('Adventure', 'Animation', 'Family')
#     Actual Labels: ('Adventure', 'Animation', 'Family')
# Movie 7622:
#     Predicted Labels: ('Documentary',)
#     Actual Labels: ('Documentary',)
# Movie 7623:
#     Predicted Labels: ('Drama', 'Romance')
#     Actual Labels: ('Comedy', 'Drama', 'Romance')
# Movie 7624:
#     Predicted Labels: ('Drama', 'Foreign')
#     Actual Labels: ('Drama', 'Foreign')
# Movie 7625:
#     Predicted Labels: ('Comedy', 'Family')
#     Actual Labels: ('Comedy', 'Drama', 'Family')
# Movie 7626:
#     Predicted Labels: ('Action', 'Adventure', 'Drama', 'Science Fiction', 'Thriller')
#     Actual Labels: ('Action', 'Adventure', 'Drama', 'Science Fiction', 'Thriller')
# Movie 7627:
#     Predicted Labels: ('Drama', 'Family')
#     Actual Labels: ('Drama', 'Family')
# Movie 7628:
#     Predicted Labels: ('Action', 'Crime')
#     Actual Labels: ('Action', 'Crime')
# Movie 7629:
#     Predicted Labels: ('Drama',)
#     Actual Labels: ('Action', 'Drama')
# Movie 7630:
#     Predicted Labels: ('Drama', 'Romance')
#     Actual Labels: ('Drama', 'Romance')
# Movie 7631:
#     Predicted Labels: ('Crime', 'Drama')
#     Actual Labels: ('Crime', 'Drama', 'TV Movie')
# Movie 7632:
#     Predicted Labels: ('Crime', 'Drama', 'Thriller')
#     Actual Labels: ('Crime', 'Thriller')
# Movie 7633:
#     Predicted Labels: ('Comedy', 'Romance')
#     Actual Labels: ('Comedy', 'Romance')
# Movie 7634:
#     Predicted Labels: ('Drama', 'Romance')
#     Actual Labels: ('Drama', 'Romance')
# Movie 7635:
#     Predicted Labels: ('Drama', 'Thriller')
#     Actual Labels: ('Drama', 'Thriller')
# Movie 7636:
#     Predicted Labels: ('Action', 'Science Fiction', 'Thriller')
#     Actual Labels: ('Action', 'Science Fiction', 'Thriller')
# Movie 7637:
#     Predicted Labels: ('Action', 'Crime', 'Thriller')
#     Actual Labels: ('Action', 'Crime', 'Thriller')
# Movie 7638:
#     Predicted Labels: ('Comedy', 'Drama')
#     Actual Labels: ('Comedy', 'Drama', 'Romance')
# Movie 7639:
#     Predicted Labels: ('Drama',)
#     Actual Labels: ('Drama',)
# Movie 7640:
#     Predicted Labels: ('Drama',)
#     Actual Labels: ('Drama',)
# Movie 7641:
#     Predicted Labels: ('Horror', 'Science Fiction')
#     Actual Labels: ('Horror', 'Science Fiction')
# Movie 7642:
#     Predicted Labels: ('Crime', 'Drama', 'Thriller')
#     Actual Labels: ('Crime', 'Drama', 'Thriller')
# Movie 7643:
#     Predicted Labels: ('Drama',)
#     Actual Labels: ('Drama',)
# Movie 7644:
#     Predicted Labels: ('Comedy',)
#     Actual Labels: ('Comedy',)
# Movie 7645:
#     Predicted Labels: ('Horror',)
#     Actual Labels: ('Horror',)
# Movie 7646:
#     Predicted Labels: ('Adventure', 'Family', 'Fantasy', 'Romance')
#     Actual Labels: ('Adventure', 'Family', 'Fantasy', 'Romance')
# Movie 7647:
#     Predicted Labels: ('Drama',)
#     Actual Labels: ('Drama',)
# Movie 7648:
#     Predicted Labels: ('Action', 'Crime', 'Drama')
#     Actual Labels: ('Action', 'Crime', 'Drama')
# Movie 7649:
#     Predicted Labels: ('Adventure', 'Fantasy', 'Science Fiction')
#     Actual Labels: ('Adventure', 'Fantasy', 'Science Fiction')
# Movie 7650:
#     Predicted Labels: ('Crime', 'Horror')
#     Actual Labels: ('Crime', 'Horror')
# Movie 7651:
#     Predicted Labels: ('Drama',)
#     Actual Labels: ('Drama',)
# Movie 7652:
#     Predicted Labels: ('Drama', 'Family')
#     Actual Labels: ('Drama', 'Family')
# Movie 7653:
#     Predicted Labels: ('Drama',)
#     Actual Labels: ('Drama', 'Romance')
# Movie 7654:
#     Predicted Labels: ('Drama',)
#     Actual Labels: ('Drama',)
# Movie 7655:
#     Predicted Labels: ('Drama', 'Foreign')
#     Actual Labels: ('Drama', 'Foreign')
# Movie 7656:
#     Predicted Labels: ('Comedy', 'Drama')
#     Actual Labels: ('Comedy', 'Drama')
# Movie 7657:
#     Predicted Labels: ('Comedy', 'Drama', 'Foreign', 'Romance')
#     Actual Labels: ('Comedy', 'Drama', 'Foreign', 'Romance')
# Movie 7658:
#     Predicted Labels: ('Horror', 'Thriller')
#     Actual Labels: ('Horror', 'Thriller')
# Movie 7659:
#     Predicted Labels: ('Drama', 'Music')
#     Actual Labels: ('Drama', 'Music')
# Movie 7660:
#     Predicted Labels: ('Foreign', 'Horror', 'Science Fiction')
#     Actual Labels: ('Foreign', 'Horror', 'Science Fiction')
# Movie 7661:
#     Predicted Labels: ('Action', 'Crime', 'Fantasy')
#     Actual Labels: ('Action', 'Crime', 'Fantasy')
# Movie 7662:
#     Predicted Labels: ('Action', 'Comedy')
#     Actual Labels: ('Action', 'Comedy')
# Movie 7663:
#     Predicted Labels: ('Drama',)
#     Actual Labels: ('Drama',)
# Movie 7664:
#     Predicted Labels: ('Comedy', 'Drama')
#     Actual Labels: ('Comedy', 'Drama')
# Movie 7665:
#     Predicted Labels: ('Comedy', 'Drama')
#     Actual Labels: ('Comedy', 'Drama')
# Movie 7666:
#     Predicted Labels: ('Drama', 'Family', 'Music', 'Romance')
#     Actual Labels: ('Family', 'Music', 'Romance')
# Movie 7667:
#     Predicted Labels: ('Comedy', 'Drama', 'Romance')
#     Actual Labels: ('Comedy', 'Drama', 'Romance')
# Movie 7668:
#     Predicted Labels: ('Drama', 'History', 'War')
#     Actual Labels: ('Drama', 'History', 'War')
# Movie 7669:
#     Predicted Labels: ('Drama', 'History', 'Romance')
#     Actual Labels: ('Drama', 'History', 'Romance')
# Movie 7670:
#     Predicted Labels: ('Comedy', 'Drama', 'Romance')
#     Actual Labels: ('Drama', 'Romance')
# Movie 7671:
#     Predicted Labels: ('Comedy', 'Drama')
#     Actual Labels: ('Comedy', 'Drama')
# Movie 7672:
#     Predicted Labels: ('Action', 'Adventure', 'Science Fiction')
#     Actual Labels: ('Action', 'Adventure', 'Science Fiction')
# Movie 7673:
#     Predicted Labels: ('Action', 'Adventure', 'Animation', 'Fantasy')
#     Actual Labels: ('Action', 'Adventure', 'Animation', 'Fantasy')
# Movie 7674:
#     Predicted Labels: ('Crime', 'Romance')
#     Actual Labels: ('Crime', 'Drama', 'Romance')
# Movie 7675:
#     Predicted Labels: ()
#     Actual Labels: ('Comedy',)
# Movie 7676:
#     Predicted Labels: ('Romance',)
#     Actual Labels: ('Comedy', 'Romance')
# Movie 7677:
#     Predicted Labels: ('Adventure', 'Animation', 'Fantasy', 'Horror', 'Science Fiction')
#     Actual Labels: ('Adventure', 'Animation', 'Fantasy', 'Horror', 'Science Fiction')
# Movie 7678:
#     Predicted Labels: ('Horror', 'Thriller')
#     Actual Labels: ('Horror', 'Thriller')
# Movie 7679:
#     Predicted Labels: ('Comedy',)
#     Actual Labels: ('Comedy',)
# Movie 7680:
#     Predicted Labels: ('Drama',)
#     Actual Labels: ('Comedy', 'Drama')
# Movie 7681:
#     Predicted Labels: ('Music',)
#     Actual Labels: ('Music',)
# Movie 7682:
#     Predicted Labels: ('Drama', 'Thriller')
#     Actual Labels: ('Drama', 'Thriller')
# Movie 7683:
#     Predicted Labels: ('Drama',)
#     Actual Labels: ('Drama',)
# Movie 7684:
#     Predicted Labels: ('Drama',)
#     Actual Labels: ('Drama',)
# Movie 7685:
#     Predicted Labels: ('Horror', 'Mystery')
#     Actual Labels: ('Horror', 'Mystery')
# Movie 7686:
#     Predicted Labels: ('Comedy', 'Mystery')
#     Actual Labels: ('Comedy', 'Mystery')
# Movie 7687:
#     Predicted Labels: ()
#     Actual Labels: ('Comedy',)
# Movie 7688:
#     Predicted Labels: ('Drama',)
#     Actual Labels: ('Drama',)
# Movie 7689:
#     Predicted Labels: ('Western',)
#     Actual Labels: ('Western',)
# Movie 7690:
#     Predicted Labels: ('Drama', 'Romance', 'Thriller')
#     Actual Labels: ('Drama', 'Romance', 'Thriller')
# Movie 7691:
#     Predicted Labels: ('Drama', 'Fantasy', 'Horror', 'Thriller')
#     Actual Labels: ('Drama', 'Fantasy', 'Horror', 'Thriller')
# Movie 7692:
#     Predicted Labels: ('Documentary',)
#     Actual Labels: ('Documentary',)
# Movie 7693:
#     Predicted Labels: ('Drama', 'History', 'War')
#     Actual Labels: ('Drama', 'History', 'War')
# Movie 7694:
#     Predicted Labels: ('Action', 'Crime', 'Foreign', 'Thriller')
#     Actual Labels: ('Action', 'Crime', 'Foreign', 'Thriller')
# Movie 7695:
#     Predicted Labels: ('Foreign', 'Thriller')
#     Actual Labels: ('Foreign', 'Thriller')
# Movie 7696:
#     Predicted Labels: ()
#     Actual Labels: ('Comedy',)
# Movie 7697:
#     Predicted Labels: ('Comedy', 'Foreign', 'Mystery', 'Romance', 'Thriller')
#     Actual Labels: ('Comedy', 'Foreign', 'Mystery', 'Romance', 'Thriller')
# Movie 7698:
#     Predicted Labels: ('Drama', 'Romance')
#     Actual Labels: ('Drama', 'Romance')
# Movie 7699:
#     Predicted Labels: ('Animation', 'Family')
#     Actual Labels: ('Animation', 'Family')
# Movie 7700:
#     Predicted Labels: ('Family', 'Fantasy')
#     Actual Labels: ('Family', 'Fantasy')
# Movie 7701:
#     Predicted Labels: ('Action', 'Comedy', 'Drama', 'Thriller')
#     Actual Labels: ('Action', 'Comedy', 'Drama', 'Thriller')
# Movie 7702:
#     Predicted Labels: ('Documentary', 'Drama')
#     Actual Labels: ('Documentary', 'Drama', 'Romance')
# Movie 7703:
#     Predicted Labels: ('Horror', 'Mystery', 'Thriller')
#     Actual Labels: ('Horror', 'Mystery', 'Thriller')
# Movie 7704:
#     Predicted Labels: ('Comedy', 'Romance')
#     Actual Labels: ('Comedy', 'Romance')
# Movie 7705:
#     Predicted Labels: ('Horror',)
#     Actual Labels: ('Horror',)
# Movie 7706:
#     Predicted Labels: ('Comedy',)
#     Actual Labels: ('Comedy',)
# Movie 7707:
#     Predicted Labels: ('Comedy', 'Fantasy', 'Romance')
#     Actual Labels: ('Comedy', 'Fantasy', 'Romance')
# Movie 7708:
#     Predicted Labels: ('Adventure', 'Animation', 'Family')
#     Actual Labels: ('Adventure', 'Animation', 'Family')
# Movie 7709:
#     Predicted Labels: ('Action', 'Science Fiction')
#     Actual Labels: ('Action', 'Adventure', 'Science Fiction')
# Movie 7710:
#     Predicted Labels: ('Comedy',)
#     Actual Labels: ('Comedy',)
# Movie 7711:
#     Predicted Labels: ('Documentary',)
#     Actual Labels: ('Documentary',)
# Movie 7712:
#     Predicted Labels: ('Documentary',)
#     Actual Labels: ('Documentary',)
# Movie 7713:
#     Predicted Labels: ('Documentary',)
#     Actual Labels: ('Documentary',)
# Movie 7714:
#     Predicted Labels: ('Drama',)
#     Actual Labels: ('Drama',)
# Movie 7715:
#     Predicted Labels: ('Drama',)
#     Actual Labels: ('Drama',)
# Movie 7716:
#     Predicted Labels: ('Drama', 'Mystery', 'Thriller')
#     Actual Labels: ('Drama', 'Mystery', 'Thriller')
# Movie 7717:
#     Predicted Labels: ('Documentary',)
#     Actual Labels: ('Documentary',)
# Movie 7718:
#     Predicted Labels: ('Science Fiction',)
#     Actual Labels: ('Science Fiction',)
# Movie 7719:
#     Predicted Labels: ('Comedy', 'Drama', 'Foreign', 'Romance')
#     Actual Labels: ('Comedy', 'Drama', 'Foreign', 'Romance')
# Movie 7720:
#     Predicted Labels: ('Action', 'Thriller')
#     Actual Labels: ('Action', 'Thriller')
# Movie 7721:
#     Predicted Labels: ('Drama',)
#     Actual Labels: ('Drama',)
# Movie 7722:
#     Predicted Labels: ('Comedy',)
#     Actual Labels: ('Comedy',)
# Movie 7723:
#     Predicted Labels: ('Adventure', 'Drama', 'Family')
#     Actual Labels: ('Adventure', 'Drama', 'Family')
# Movie 7724:
#     Predicted Labels: ()
#     Actual Labels: ()
# Movie 7725:
#     Predicted Labels: ('Western',)
#     Actual Labels: ('Western',)
# Movie 7726:
#     Predicted Labels: ('Comedy', 'Drama', 'Romance')
#     Actual Labels: ('Comedy', 'Drama', 'Romance')
# Movie 7727:
#     Predicted Labels: ('Action', 'Crime', 'Drama', 'Foreign', 'Thriller')
#     Actual Labels: ('Action', 'Crime', 'Drama', 'Foreign', 'Thriller')
# Movie 7728:
#     Predicted Labels: ('Drama', 'Fantasy')
#     Actual Labels: ('Drama', 'Fantasy')
# Movie 7729:
#     Predicted Labels: ('Comedy', 'Horror', 'Science Fiction')
#     Actual Labels: ('Comedy', 'Horror', 'Science Fiction')
# Movie 7730:
#     Predicted Labels: ('Comedy', 'Drama', 'Family', 'Romance')
#     Actual Labels: ('Comedy', 'Drama', 'Family', 'Romance')
# Movie 7731:
#     Predicted Labels: ('Comedy',)
#     Actual Labels: ('Comedy',)
# Movie 7732:
#     Predicted Labels: ('Comedy',)
#     Actual Labels: ('Comedy', 'Romance')
# Movie 7733:
#     Predicted Labels: ('Comedy', 'Drama', 'Foreign')
#     Actual Labels: ('Comedy', 'Drama', 'Foreign')
# Movie 7734:
#     Predicted Labels: ('Comedy',)
#     Actual Labels: ('Comedy',)
# Movie 7735:
#     Predicted Labels: ('Comedy',)
#     Actual Labels: ('Comedy',)
# Movie 7736:
#     Predicted Labels: ('Drama', 'Romance')
#     Actual Labels: ('Drama', 'Romance')
# Movie 7737:
#     Predicted Labels: ('Drama', 'Mystery', 'TV Movie', 'Thriller')
#     Actual Labels: ('Drama', 'Mystery', 'TV Movie', 'Thriller')
# Movie 7738:
#     Predicted Labels: ('Crime', 'Documentary')
#     Actual Labels: ('Crime', 'Documentary')
# Movie 7739:
#     Predicted Labels: ('Drama', 'Romance')
#     Actual Labels: ('Drama', 'Romance')
# Movie 7740:
#     Predicted Labels: ('Documentary',)
#     Actual Labels: ('Documentary',)
# Movie 7741:
#     Predicted Labels: ('Comedy', 'Romance')
#     Actual Labels: ('Comedy', 'Romance')
# Movie 7742:
#     Predicted Labels: ('Drama', 'Western')
#     Actual Labels: ('Drama', 'Western')
# Movie 7743:
#     Predicted Labels: ('Thriller',)
#     Actual Labels: ('Thriller',)
# Movie 7744:
#     Predicted Labels: ('Documentary', 'Horror')
#     Actual Labels: ('Documentary', 'Horror')
# Movie 7745:
#     Predicted Labels: ('Adventure', 'Family')
#     Actual Labels: ('Adventure', 'Family')
# Movie 7746:
#     Predicted Labels: ('Comedy',)
#     Actual Labels: ('Comedy', 'Romance')
# Movie 7747:
#     Predicted Labels: ('Drama',)
#     Actual Labels: ('Drama',)
# Movie 7748:
#     Predicted Labels: ('Adventure',)
#     Actual Labels: ('Adventure',)
# Movie 7749:
#     Predicted Labels: ('Crime', 'Drama')
#     Actual Labels: ('Crime', 'Drama')
# Movie 7750:
#     Predicted Labels: ()
#     Actual Labels: ()
# Movie 7751:
#     Predicted Labels: ('Action', 'Drama')
#     Actual Labels: ('Action', 'Drama')
# Movie 7752:
#     Predicted Labels: ('Crime', 'Drama', 'Horror', 'Thriller')
#     Actual Labels: ('Crime', 'Drama', 'Horror')
# Movie 7753:
#     Predicted Labels: ('Comedy',)
#     Actual Labels: ('Comedy',)
# Movie 7754:
#     Predicted Labels: ('Comedy', 'Drama')
#     Actual Labels: ('Comedy', 'Drama')
# Movie 7755:
#     Predicted Labels: ('Documentary', 'Foreign')
#     Actual Labels: ('Documentary', 'Foreign')
# Movie 7756:
#     Predicted Labels: ('Comedy',)
#     Actual Labels: ('Comedy',)
# Movie 7757:
#     Predicted Labels: ('Adventure',)
#     Actual Labels: ('Adventure',)
# Movie 7758:
#     Predicted Labels: ('Comedy', 'Drama', 'Romance')
#     Actual Labels: ('Comedy', 'Romance')
# Movie 7759:
#     Predicted Labels: ('Comedy',)
#     Actual Labels: ('Comedy',)
# Movie 7760:
#     Predicted Labels: ('Documentary',)
#     Actual Labels: ('Documentary',)
# Movie 7761:
#     Predicted Labels: ('Thriller',)
#     Actual Labels: ('Thriller',)
# Movie 7762:
#     Predicted Labels: ('Comedy',)
#     Actual Labels: ('Comedy',)
# Movie 7763:
#     Predicted Labels: ('Drama',)
#     Actual Labels: ('Drama',)
# Movie 7764:
#     Predicted Labels: ('Comedy',)
#     Actual Labels: ('Comedy',)
# Movie 7765:
#     Predicted Labels: ('Drama',)
#     Actual Labels: ('Drama',)
# Movie 7766:
#     Predicted Labels: ('Action', 'Adventure', 'Comedy', 'Fantasy', 'Romance')
#     Actual Labels: ('Action', 'Adventure', 'Comedy', 'Drama', 'Fantasy', 'Romance')
# Movie 7767:
#     Predicted Labels: ()
#     Actual Labels: ()
# Movie 7768:
#     Predicted Labels: ('Documentary',)
#     Actual Labels: ('Documentary',)
# Movie 7769:
#     Predicted Labels: ('Horror', 'Thriller')
#     Actual Labels: ('Horror', 'Thriller')
# Movie 7770:
#     Predicted Labels: ('Documentary',)
#     Actual Labels: ('Documentary',)
# Movie 7771:
#     Predicted Labels: ('Horror',)
#     Actual Labels: ('Horror',)
# Movie 7772:
#     Predicted Labels: ('Comedy',)
#     Actual Labels: ('Comedy',)
# Movie 7773:
#     Predicted Labels: ('Documentary', 'Music')
#     Actual Labels: ('Documentary', 'Music')
# Movie 7774:
#     Predicted Labels: ('Drama', 'Fantasy', 'Horror', 'Mystery', 'Thriller')
#     Actual Labels: ('Drama', 'Fantasy', 'Horror', 'Mystery', 'Thriller')
# Movie 7775:
#     Predicted Labels: ('Crime',)
#     Actual Labels: ('Crime',)
# Movie 7776:
#     Predicted Labels: ('Drama', 'Foreign')
#     Actual Labels: ('Drama', 'Foreign')
# Movie 7777:
#     Predicted Labels: ('Drama', 'Foreign')
#     Actual Labels: ('Drama', 'Foreign')
# Movie 7778:
#     Predicted Labels: ('Action', 'Crime', 'Drama')
#     Actual Labels: ('Action', 'Crime', 'Drama')
# Movie 7779:
#     Predicted Labels: ('Crime', 'Drama', 'Foreign', 'Music', 'Romance')
#     Actual Labels: ('Crime', 'Drama', 'Foreign', 'Music', 'Romance')
# Movie 7780:
#     Predicted Labels: ('Drama', 'History', 'War')
#     Actual Labels: ('Drama', 'History', 'War')
# Movie 7781:
#     Predicted Labels: ('Comedy', 'Crime')
#     Actual Labels: ('Comedy', 'Crime')
# Movie 7782:
#     Predicted Labels: ('Comedy', 'Crime', 'Drama')
#     Actual Labels: ('Comedy', 'Crime', 'Drama')
# Movie 7783:
#     Predicted Labels: ('Drama',)
#     Actual Labels: ('Drama',)
# Movie 7784:
#     Predicted Labels: ('Adventure', 'Animation', 'Comedy', 'Family')
#     Actual Labels: ('Adventure', 'Animation', 'Comedy', 'Family')
# Movie 7785:
#     Predicted Labels: ('Horror',)
#     Actual Labels: ('Horror',)
# Movie 7786:
#     Predicted Labels: ('Animation', 'Family')
#     Actual Labels: ('Animation', 'Family')
# Movie 7787:
#     Predicted Labels: ('Thriller',)
#     Actual Labels: ('Thriller',)
# Movie 7788:
#     Predicted Labels: ('Drama', 'Romance')
#     Actual Labels: ('Drama', 'Romance')
# Movie 7789:
#     Predicted Labels: ('Crime', 'Documentary', 'History', 'Horror')
#     Actual Labels: ('Crime', 'Documentary', 'History', 'Horror')
# Movie 7790:
#     Predicted Labels: ('Action', 'Crime')
#     Actual Labels: ('Action', 'Drama')
# Movie 7791:
#     Predicted Labels: ('Crime', 'Mystery', 'Thriller')
#     Actual Labels: ('Crime', 'Mystery', 'Thriller')
# Movie 7792:
#     Predicted Labels: ('Western',)
#     Actual Labels: ('Western',)
# Movie 7793:
#     Predicted Labels: ('Comedy', 'Horror')
#     Actual Labels: ('Comedy',)
# Movie 7794:
#     Predicted Labels: ('Adventure', 'Comedy', 'Family')
#     Actual Labels: ('Adventure', 'Comedy', 'Family')
# Movie 7795:
#     Predicted Labels: ()
#     Actual Labels: ()
# Movie 7796:
#     Predicted Labels: ('Family',)
#     Actual Labels: ('Family',)
# Movie 7797:
#     Predicted Labels: ('Comedy', 'Drama')
#     Actual Labels: ('Comedy', 'Drama')
# Movie 7798:
#     Predicted Labels: ('Drama', 'History', 'Romance')
#     Actual Labels: ('Drama', 'History', 'Romance')
# Movie 7799:
#     Predicted Labels: ('Action', 'Thriller')
#     Actual Labels: ('Action', 'Thriller')
# Movie 7800:
#     Predicted Labels: ('Drama', 'Romance')
#     Actual Labels: ('Drama', 'Romance')
# Movie 7801:
#     Predicted Labels: ('Action',)
#     Actual Labels: ('Action',)
# Movie 7802:
#     Predicted Labels: ('Comedy', 'History')
#     Actual Labels: ('Comedy',)
# Movie 7803:
#     Predicted Labels: ('Animation',)
#     Actual Labels: ('Animation',)
# Movie 7804:
#     Predicted Labels: ('Action', 'Crime', 'Foreign')
#     Actual Labels: ('Action', 'Crime', 'Foreign')
# Movie 7805:
#     Predicted Labels: ('Action', 'Thriller')
#     Actual Labels: ('Action', 'Thriller')
# Movie 7806:
#     Predicted Labels: ('Action', 'Adventure', 'Drama', 'War')
#     Actual Labels: ('Action', 'Adventure', 'Drama', 'War')
# Movie 7807:
#     Predicted Labels: ('Comedy', 'Crime', 'Drama')
#     Actual Labels: ('Comedy', 'Crime', 'Drama')
# Movie 7808:
#     Predicted Labels: ('Comedy', 'Horror')
#     Actual Labels: ('Comedy', 'Horror')
# Movie 7809:
#     Predicted Labels: ('Drama', 'Romance')
#     Actual Labels: ('Drama', 'Romance')
# Movie 7810:
#     Predicted Labels: ()
#     Actual Labels: ()
# Movie 7811:
#     Predicted Labels: ('Action', 'Crime', 'Drama', 'Thriller')
#     Actual Labels: ('Action', 'Crime', 'Drama')
# Movie 7812:
#     Predicted Labels: ('Mystery', 'Thriller')
#     Actual Labels: ('Mystery', 'Thriller')
# Movie 7813:
#     Predicted Labels: ('Action', 'Crime', 'Thriller')
#     Actual Labels: ('Action', 'Crime', 'Thriller')
# Movie 7814:
#     Predicted Labels: ('Comedy',)
#     Actual Labels: ('Comedy',)
# Movie 7815:
#     Predicted Labels: ('Documentary',)
#     Actual Labels: ('Documentary',)
# Movie 7816:
#     Predicted Labels: ('Comedy', 'Music', 'Romance')
#     Actual Labels: ('Music', 'Romance')
# Movie 7817:
#     Predicted Labels: ('Drama',)
#     Actual Labels: ('Drama',)
# Movie 7818:
#     Predicted Labels: ('Adventure', 'Science Fiction')
#     Actual Labels: ('Adventure', 'Mystery', 'Science Fiction')
# Movie 7819:
#     Predicted Labels: ('Documentary',)
#     Actual Labels: ('Documentary',)
# Movie 7820:
#     Predicted Labels: ('Animation', 'Comedy', 'Family', 'Fantasy')
#     Actual Labels: ('Animation', 'Comedy', 'Family', 'Fantasy')
# Movie 7821:
#     Predicted Labels: ('Adventure', 'Comedy', 'Crime')
#     Actual Labels: ('Adventure', 'Comedy', 'Crime')
# Movie 7822:
#     Predicted Labels: ('Documentary',)
#     Actual Labels: ('Documentary',)
# Movie 7823:
#     Predicted Labels: ('Comedy', 'Drama', 'Romance')
#     Actual Labels: ('Comedy', 'Drama', 'Romance')
# Movie 7824:
#     Predicted Labels: ('Documentary',)
#     Actual Labels: ('Documentary',)
# Movie 7825:
#     Predicted Labels: ('Drama',)
#     Actual Labels: ('Drama',)
# Movie 7826:
#     Predicted Labels: ('Comedy',)
#     Actual Labels: ('Comedy',)
# Movie 7827:
#     Predicted Labels: ('Animation',)
#     Actual Labels: ('Animation',)
# Movie 7828:
#     Predicted Labels: ('Comedy',)
#     Actual Labels: ('Comedy',)
# Movie 7829:
#     Predicted Labels: ('Action', 'Drama', 'Mystery', 'Thriller')
#     Actual Labels: ('Action', 'Drama', 'Mystery', 'Thriller')
# Movie 7830:
#     Predicted Labels: ('Drama',)
#     Actual Labels: ()
# Movie 7831:
#     Predicted Labels: ('Drama',)
#     Actual Labels: ('Drama',)
# Movie 7832:
#     Predicted Labels: ('Comedy',)
#     Actual Labels: ('Comedy',)
# Movie 7833:
#     Predicted Labels: ('Fantasy', 'Romance')
#     Actual Labels: ('Drama', 'Fantasy', 'Romance')
# Movie 7834:
#     Predicted Labels: ('Drama',)
#     Actual Labels: ('Drama',)
# Movie 7835:
#     Predicted Labels: ('Documentary', 'Romance')
#     Actual Labels: ('Documentary', 'Romance')
# Movie 7836:
#     Predicted Labels: ('Adventure', 'Drama', 'History')
#     Actual Labels: ('Adventure', 'Drama', 'History')
# Movie 7837:
#     Predicted Labels: ()
#     Actual Labels: ('Comedy',)
# Movie 7838:
#     Predicted Labels: ('Comedy', 'Drama', 'Romance')
#     Actual Labels: ('Comedy', 'Drama', 'Romance')
# Movie 7839:
#     Predicted Labels: ('Drama',)
#     Actual Labels: ('Drama',)
# Movie 7840:
#     Predicted Labels: ('Documentary', 'Drama')
#     Actual Labels: ('Documentary', 'Drama')
# Movie 7841:
#     Predicted Labels: ('Comedy', 'Drama')
#     Actual Labels: ('Comedy', 'Drama')
# Movie 7842:
#     Predicted Labels: ('Documentary',)
#     Actual Labels: ('Documentary',)
# Movie 7843:
#     Predicted Labels: ('Adventure', 'Animation', 'Family', 'Fantasy')
#     Actual Labels: ('Adventure', 'Animation', 'Family', 'Fantasy')
# Movie 7844:
#     Predicted Labels: ('Comedy', 'Drama', 'Family')
#     Actual Labels: ('Comedy', 'Drama')
# Movie 7845:
#     Predicted Labels: ('Drama',)
#     Actual Labels: ('Drama',)
# Movie 7846:
#     Predicted Labels: ('Comedy', 'Mystery')
#     Actual Labels: ('Comedy', 'Mystery')
# Movie 7847:
#     Predicted Labels: ('Action', 'Crime', 'Western')
#     Actual Labels: ('Action', 'Crime', 'Western')
# Movie 7848:
#     Predicted Labels: ('Drama',)
#     Actual Labels: ('Drama',)
# Movie 7849:
#     Predicted Labels: ('Crime', 'Romance')
#     Actual Labels: ('Crime', 'Drama', 'Romance')
# Movie 7850:
#     Predicted Labels: ('Action', 'Adventure', 'Crime', 'Thriller')
#     Actual Labels: ('Action', 'Adventure', 'Crime', 'Thriller')
# Movie 7851:
#     Predicted Labels: ('Animation', 'Drama', 'Family')
#     Actual Labels: ('Animation', 'Family')
# Movie 7852:
#     Predicted Labels: ('Comedy', 'Horror')
#     Actual Labels: ('Comedy', 'Horror')
# Movie 7853:
#     Predicted Labels: ('Drama',)
#     Actual Labels: ('Drama',)
# Movie 7854:
#     Predicted Labels: ('Drama',)
#     Actual Labels: ('Drama',)
# Movie 7855:
#     Predicted Labels: ('Crime', 'Mystery', 'Thriller')
#     Actual Labels: ('Crime', 'Mystery', 'Thriller')
# Movie 7856:
#     Predicted Labels: ('Comedy',)
#     Actual Labels: ('Comedy',)
# Movie 7857:
#     Predicted Labels: ('Drama',)
#     Actual Labels: ('Drama',)
# Movie 7858:
#     Predicted Labels: ('Drama',)
#     Actual Labels: ('Drama',)
# Movie 7859:
#     Predicted Labels: ('Action', 'Adventure', 'Animation', 'Fantasy', 'Science Fiction')
#     Actual Labels: ('Action', 'Adventure', 'Animation', 'Fantasy', 'Science Fiction')
# Movie 7860:
#     Predicted Labels: ('Action', 'Drama')
#     Actual Labels: ('Action', 'Drama')
# Movie 7861:
#     Predicted Labels: ('Comedy',)
#     Actual Labels: ('Comedy',)
# Movie 7862:
#     Predicted Labels: ('Action',)
#     Actual Labels: ('Action',)
# Movie 7863:
#     Predicted Labels: ('Drama',)
#     Actual Labels: ('Drama',)
# Movie 7864:
#     Predicted Labels: ()
#     Actual Labels: ()
# Movie 7865:
#     Predicted Labels: ('Crime', 'Drama')
#     Actual Labels: ('Crime', 'Drama')
# Movie 7866:
#     Predicted Labels: ('Action', 'Drama', 'Mystery', 'Thriller')
#     Actual Labels: ('Action', 'Drama', 'Mystery', 'Thriller')
# Movie 7867:
#     Predicted Labels: ('Drama', 'Romance')
#     Actual Labels: ('Drama', 'Romance')
# Movie 7868:
#     Predicted Labels: ()
#     Actual Labels: ()
# Movie 7869:
#     Predicted Labels: ('Comedy', 'Drama', 'Romance')
#     Actual Labels: ('Comedy', 'Drama', 'Romance')
# Movie 7870:
#     Predicted Labels: ('Mystery',)
#     Actual Labels: ('Mystery',)
# Movie 7871:
#     Predicted Labels: ('Drama', 'History', 'Thriller')
#     Actual Labels: ('Drama', 'History', 'Thriller')
# Movie 7872:
#     Predicted Labels: ('Comedy', 'Drama')
#     Actual Labels: ('Comedy', 'Drama')
# Movie 7873:
#     Predicted Labels: ('Drama', 'Horror', 'Mystery', 'Thriller')
#     Actual Labels: ('Drama', 'Horror', 'Mystery', 'Thriller')
# Movie 7874:
#     Predicted Labels: ('Comedy', 'Drama')
#     Actual Labels: ('Comedy', 'Drama')
# Movie 7875:
#     Predicted Labels: ('Action', 'Drama', 'Romance')
#     Actual Labels: ('Action', 'Drama', 'Romance')
# Movie 7876:
#     Predicted Labels: ('Animation',)
#     Actual Labels: ('Animation',)
# Movie 7877:
#     Predicted Labels: ('Action', 'Comedy')
#     Actual Labels: ('Action', 'Comedy')
# Movie 7878:
#     Predicted Labels: ('Science Fiction', 'Thriller')
#     Actual Labels: ('Science Fiction', 'Thriller')
# Movie 7879:
#     Predicted Labels: ('Comedy', 'Crime', 'Drama', 'Mystery', 'Thriller')
#     Actual Labels: ('Comedy', 'Crime', 'Drama', 'Mystery', 'Thriller')
# Movie 7880:
#     Predicted Labels: ()
#     Actual Labels: ()
# Movie 7881:
#     Predicted Labels: ('Comedy',)
#     Actual Labels: ('Comedy',)
# Movie 7882:
#     Predicted Labels: ('Documentary',)
#     Actual Labels: ('Documentary',)
# Movie 7883:
#     Predicted Labels: ('Horror',)
#     Actual Labels: ('Horror',)
# Movie 7884:
#     Predicted Labels: ('Comedy',)
#     Actual Labels: ('Comedy',)
# Movie 7885:
#     Predicted Labels: ('Comedy',)
#     Actual Labels: ('Comedy',)
# Movie 7886:
#     Predicted Labels: ('Comedy',)
#     Actual Labels: ('Comedy', 'TV Movie')
# Movie 7887:
#     Predicted Labels: ('Documentary',)
#     Actual Labels: ('Documentary',)
# Movie 7888:
#     Predicted Labels: ('Drama', 'Family')
#     Actual Labels: ('Drama', 'Family')
# Movie 7889:
#     Predicted Labels: ('Family', 'TV Movie')
#     Actual Labels: ('Family', 'TV Movie')
# Movie 7890:
#     Predicted Labels: ('Drama',)
#     Actual Labels: ('Comedy', 'Drama')
# Movie 7891:
#     Predicted Labels: ('Drama',)
#     Actual Labels: ()
# Movie 7892:
#     Predicted Labels: ('Horror', 'Mystery')
#     Actual Labels: ('Horror', 'Mystery')
# Movie 7893:
#     Predicted Labels: ('Drama', 'Science Fiction', 'Thriller')
#     Actual Labels: ('Drama', 'Science Fiction', 'Thriller')
# Movie 7894:
#     Predicted Labels: ('Drama',)
#     Actual Labels: ('Drama',)
# Movie 7895:
#     Predicted Labels: ('Adventure', 'Crime')
#     Actual Labels: ('Adventure', 'Crime')
# Movie 7896:
#     Predicted Labels: ('Action', 'Drama', 'Thriller')
#     Actual Labels: ('Action', 'Drama', 'Thriller')
# Movie 7897:
#     Predicted Labels: ('Animation', 'Family')
#     Actual Labels: ('Animation', 'Family')
# Movie 7898:
#     Predicted Labels: ('Horror', 'Thriller')
#     Actual Labels: ('Horror', 'Thriller')
# Movie 7899:
#     Predicted Labels: ('Crime', 'Drama')
#     Actual Labels: ('Crime', 'Drama')
# Movie 7900:
#     Predicted Labels: ('Horror',)
#     Actual Labels: ('Horror',)
# Movie 7901:
#     Predicted Labels: ('Comedy', 'Crime', 'Drama')
#     Actual Labels: ('Comedy', 'Crime', 'Drama')
# Movie 7902:
#     Predicted Labels: ('Drama',)
#     Actual Labels: ('Drama',)
# Movie 7903:
#     Predicted Labels: ('Comedy', 'Crime', 'Thriller')
#     Actual Labels: ('Comedy', 'Crime', 'Thriller')
# Movie 7904:
#     Predicted Labels: ('Horror', 'Mystery', 'Thriller')
#     Actual Labels: ('Horror', 'Mystery', 'Thriller')
# Movie 7905:
#     Predicted Labels: ('Documentary', 'Science Fiction')
#     Actual Labels: ('Documentary', 'Science Fiction')
# Movie 7906:
#     Predicted Labels: ('Comedy',)
#     Actual Labels: ('Comedy',)
# Movie 7907:
#     Predicted Labels: ('Drama',)
#     Actual Labels: ('Drama',)
# Movie 7908:
#     Predicted Labels: ('Action', 'Crime', 'Drama', 'Thriller')
#     Actual Labels: ('Action', 'Crime', 'Drama', 'Thriller')
# Movie 7909:
#     Predicted Labels: ('Action', 'Drama', 'War')
#     Actual Labels: ('Action', 'Drama', 'War')
# Movie 7910:
#     Predicted Labels: ('Action', 'Crime', 'Drama', 'Thriller')
# ...
#     Actual Labels: ('Comedy', 'Drama')
# Movie 8928:
#     Predicted Labels: ('Action', 'Comedy')
#     Actual Labels: ('Action', 'Comedy')
# Movie 8929:
#     Predicted Labels: ('Crime',)
#     Actual Labels: ('Crime',)
# Movie 8930:
#     Predicted Labels: ('Music',)
#     Actual Labels: ('Music',)
# Movie 8931:
#     Predicted Labels: ('Action', 'Comedy', 'Drama')
#     Actual Labels: ('Action', 'Comedy', 'Drama')
# Movie 8932:
#     Predicted Labels: ('Drama',)
#     Actual Labels: ('Comedy', 'Drama')
# Movie 8933:
#     Predicted Labels: ('Drama',)
#     Actual Labels: ('Drama',)
# Movie 8934:
#     Predicted Labels: ('Romance',)
#     Actual Labels: ('Comedy', 'Romance')
# Movie 8935:
#     Predicted Labels: ()
#     Actual Labels: ()
# Movie 8936:
#     Predicted Labels: ('Documentary',)
#     Actual Labels: ('Documentary',)
# Movie 8937:
#     Predicted Labels: ('Drama', 'Romance')
#     Actual Labels: ('Drama', 'Romance')
# Movie 8938:
#     Predicted Labels: ('Comedy',)
#     Actual Labels: ('Comedy',)
# Movie 8939:
#     Predicted Labels: ('Action', 'Adventure', 'Family')
#     Actual Labels: ('Action', 'Adventure', 'Family')
# Movie 8940:
#     Predicted Labels: ('Drama', 'Music', 'Romance')
#     Actual Labels: ('Drama', 'Music', 'Romance')
# Movie 8941:
#     Predicted Labels: ('Drama', 'War')
#     Actual Labels: ('Drama', 'War')
# Movie 8942:
#     Predicted Labels: ('Drama', 'Foreign')
#     Actual Labels: ('Drama', 'Foreign')
# Movie 8943:
#     Predicted Labels: ('Comedy', 'Family', 'Music')
#     Actual Labels: ('Comedy', 'Family', 'Music')
# Movie 8944:
#     Predicted Labels: ('Comedy',)
#     Actual Labels: ('Comedy',)
# Movie 8945:
#     Predicted Labels: ()
#     Actual Labels: ()
# Movie 8946:
#     Predicted Labels: ('Drama',)
#     Actual Labels: ('Drama',)
# Movie 8947:
#     Predicted Labels: ('Adventure', 'Science Fiction')
#     Actual Labels: ('Adventure', 'Horror', 'Science Fiction')
# Movie 8948:
#     Predicted Labels: ('Drama', 'War')
#     Actual Labels: ('Drama', 'War')
# Movie 8949:
#     Predicted Labels: ('Drama',)
#     Actual Labels: ('Drama',)
# Movie 8950:
#     Predicted Labels: ('Animation',)
#     Actual Labels: ('Animation',)
# Movie 8951:
#     Predicted Labels: ('Romance', 'Western')
#     Actual Labels: ('Romance', 'Western')
# Movie 8952:
#     Predicted Labels: ('Drama',)
#     Actual Labels: ('Drama',)
# Movie 8953:
#     Predicted Labels: ('Thriller',)
#     Actual Labels: ('Thriller',)
# Movie 8954:
#     Predicted Labels: ('Drama', 'History')
#     Actual Labels: ('Drama', 'History')
# Movie 8955:
#     Predicted Labels: ('Drama',)
#     Actual Labels: ('Drama',)
# Movie 8956:
#     Predicted Labels: ('Drama',)
#     Actual Labels: ('Drama',)
# Movie 8957:
#     Predicted Labels: ('Comedy', 'Romance')
#     Actual Labels: ('Comedy', 'Romance')
# Movie 8958:
#     Predicted Labels: ('Drama', 'Romance')
#     Actual Labels: ('Drama', 'Romance')
# Movie 8959:
#     Predicted Labels: ('Documentary', 'Music')
#     Actual Labels: ('Documentary', 'Music')
# Movie 8960:
#     Predicted Labels: ()
#     Actual Labels: ()
# Movie 8961:
#     Predicted Labels: ('Drama', 'Foreign')
#     Actual Labels: ('Drama', 'Foreign')
# Movie 8962:
#     Predicted Labels: ('Comedy', 'Drama')
#     Actual Labels: ('Comedy', 'Drama')
# Movie 8963:
#     Predicted Labels: ('Action', 'Crime', 'Drama')
#     Actual Labels: ('Action', 'Crime', 'Drama', 'Thriller')
# Movie 8964:
#     Predicted Labels: ('Crime', 'Horror')
#     Actual Labels: ('Crime', 'Horror')
# Movie 8965:
#     Predicted Labels: ('Documentary',)
#     Actual Labels: ('Documentary',)
# Movie 8966:
#     Predicted Labels: ('Animation', 'Drama')
#     Actual Labels: ('Animation', 'Drama', 'Fantasy')
# Movie 8967:
#     Predicted Labels: ('Action', 'Adventure', 'Drama', 'War')
#     Actual Labels: ('Action', 'Adventure', 'Drama', 'War')
# Movie 8968:
#     Predicted Labels: ('Drama', 'Music', 'Romance')
#     Actual Labels: ('Drama', 'Music', 'Romance')
# Movie 8969:
#     Predicted Labels: ('Action', 'Animation', 'Western')
#     Actual Labels: ('Action', 'Animation', 'Western')
# Movie 8970:
#     Predicted Labels: ('Action', 'Adventure', 'Animation')
#     Actual Labels: ('Action', 'Adventure', 'Animation')
# Movie 8971:
#     Predicted Labels: ('Action', 'Comedy', 'Drama')
#     Actual Labels: ('Action', 'Comedy', 'Drama')
# Movie 8972:
#     Predicted Labels: ('Action', 'Drama', 'Foreign', 'Romance')
#     Actual Labels: ('Action', 'Drama', 'Foreign', 'Romance')
# Movie 8973:
#     Predicted Labels: ('Comedy', 'Drama')
#     Actual Labels: ('Comedy', 'Drama')
# Movie 8974:
#     Predicted Labels: ('Action', 'Crime', 'Foreign', 'Thriller')
#     Actual Labels: ('Action', 'Crime', 'Drama', 'Foreign', 'Thriller')
# Movie 8975:
#     Predicted Labels: ('Drama', 'History')
#     Actual Labels: ('Drama', 'History')
# Movie 8976:
#     Predicted Labels: ()
#     Actual Labels: ('Drama',)
# Movie 8977:
#     Predicted Labels: ('Drama',)
#     Actual Labels: ('Drama',)
# Movie 8978:
#     Predicted Labels: ('Drama',)
#     Actual Labels: ('Drama',)
# Movie 8979:
#     Predicted Labels: ('Comedy', 'Drama', 'Romance')
#     Actual Labels: ('Comedy', 'Drama', 'Romance')
# Movie 8980:
#     Predicted Labels: ('Romance',)
#     Actual Labels: ('Romance',)
# Movie 8981:
#     Predicted Labels: ()
#     Actual Labels: ()
# Movie 8982:
#     Predicted Labels: ('Drama', 'Foreign', 'History')
#     Actual Labels: ('Drama', 'Foreign', 'History')
# Movie 8983:
#     Predicted Labels: ('Horror',)
#     Actual Labels: ('Horror',)
# Movie 8984:
#     Predicted Labels: ('Comedy', 'Family', 'Fantasy')
#     Actual Labels: ('Comedy', 'Family', 'Fantasy')
# Movie 8985:
#     Predicted Labels: ('Animation', 'Mystery')
#     Actual Labels: ('Animation', 'Mystery')
# Movie 8986:
#     Predicted Labels: ('Horror', 'Thriller')
#     Actual Labels: ('Horror', 'Thriller')
# Movie 8987:
#     Predicted Labels: ('Documentary',)
#     Actual Labels: ('Documentary',)
# Movie 8988:
#     Predicted Labels: ('Drama', 'Romance')
#     Actual Labels: ('Drama', 'Romance')
# Movie 8989:
#     Predicted Labels: ('Drama',)
#     Actual Labels: ('Drama',)
# Movie 8990:
#     Predicted Labels: ('Comedy',)
#     Actual Labels: ('Comedy',)
# Movie 8991:
#     Predicted Labels: ('Comedy', 'Crime', 'Music', 'Thriller')
#     Actual Labels: ('Comedy', 'Crime', 'Music', 'Thriller')
# Movie 8992:
#     Predicted Labels: ('Comedy', 'Drama', 'Fantasy', 'Horror')
#     Actual Labels: ('Comedy', 'Drama', 'Fantasy', 'Horror')
# Movie 8993:
#     Predicted Labels: ('Science Fiction', 'TV Movie', 'Thriller')
#     Actual Labels: ('Science Fiction', 'TV Movie', 'Thriller')
# Movie 8994:
#     Predicted Labels: ()
#     Actual Labels: ()
# Movie 8995:
#     Predicted Labels: ('Documentary',)
#     Actual Labels: ('Documentary',)
# Movie 8996:
#     Predicted Labels: ('Horror', 'Thriller')
#     Actual Labels: ('Horror', 'Thriller')
# Movie 8997:
#     Predicted Labels: ('Comedy',)
#     Actual Labels: ('Comedy',)
# Movie 8998:
#     Predicted Labels: ('Comedy', 'Crime', 'Drama')
#     Actual Labels: ('Comedy', 'Crime', 'Drama')
# Movie 8999:
#     Predicted Labels: ('Action', 'Western')
#     Actual Labels: ('Action', 'Western')
# Movie 9000:
#     Predicted Labels: ('Comedy', 'Romance')
#     Actual Labels: ('Comedy', 'Romance')
# Movie 9001:
#     Predicted Labels: ('Comedy', 'Science Fiction')
#     Actual Labels: ('Comedy', 'Science Fiction')
# Movie 9002:
#     Predicted Labels: ('Drama', 'Romance')
#     Actual Labels: ('Drama', 'Romance')
# Movie 9003:
#     Predicted Labels: ('Comedy', 'Fantasy', 'Romance', 'Science Fiction')
#     Actual Labels: ('Comedy', 'Fantasy', 'Romance', 'Science Fiction')
# Movie 9004:
#     Predicted Labels: ('Adventure', 'Family', 'Fantasy')
#     Actual Labels: ('Adventure', 'Family', 'Fantasy')
# Movie 9005:
#     Predicted Labels: ('Horror', 'Thriller')
#     Actual Labels: ('Horror', 'Thriller')
# Movie 9006:
#     Predicted Labels: ('Documentary',)
#     Actual Labels: ('Documentary',)
# Movie 9007:
#     Predicted Labels: ('Drama',)
#     Actual Labels: ('Drama',)
# Movie 9008:
#     Predicted Labels: ('Horror', 'Thriller')
#     Actual Labels: ('Horror', 'Thriller')
# Movie 9009:
#     Predicted Labels: ('Drama', 'Romance')
#     Actual Labels: ('Drama', 'Romance')
# Movie 9010:
#     Predicted Labels: ('Action',)
#     Actual Labels: ('Action',)
# Movie 9011:
#     Predicted Labels: ('Drama',)
#     Actual Labels: ()
# Movie 9012:
#     Predicted Labels: ('Comedy', 'Romance')
#     Actual Labels: ('Comedy', 'Romance')
# Movie 9013:
#     Predicted Labels: ('Drama',)
#     Actual Labels: ('Drama',)
# Movie 9014:
#     Predicted Labels: ('Action', 'Western')
#     Actual Labels: ('Action', 'Western')
# Movie 9015:
#     Predicted Labels: ('Action', 'Adventure')
#     Actual Labels: ('Action', 'Adventure')
# Movie 9016:
#     Predicted Labels: ()
#     Actual Labels: ()
# Movie 9017:
#     Predicted Labels: ('Comedy',)
#     Actual Labels: ('Comedy',)
# Movie 9018:
#     Predicted Labels: ('Drama', 'Music')
#     Actual Labels: ('Drama', 'Music')
# Movie 9019:
#     Predicted Labels: ('Action', 'Thriller')
#     Actual Labels: ('Action', 'Thriller')
# Movie 9020:
#     Predicted Labels: ('Drama',)
#     Actual Labels: ('Drama',)
# Movie 9021:
#     Predicted Labels: ('Comedy', 'Romance')
#     Actual Labels: ('Comedy', 'Romance')
# Movie 9022:
#     Predicted Labels: ('Action', 'Drama')
#     Actual Labels: ('Action', 'Drama')
# Movie 9023:
#     Predicted Labels: ('Crime', 'Drama', 'Thriller')
#     Actual Labels: ('Crime', 'Drama', 'TV Movie', 'Thriller')
# Movie 9024:
#     Predicted Labels: ('Crime', 'Mystery')
#     Actual Labels: ('Crime', 'Mystery')
# Movie 9025:
#     Predicted Labels: ('Crime', 'Drama')
#     Actual Labels: ('Crime', 'Drama')
# Movie 9026:
#     Predicted Labels: ('Action', 'Crime', 'Thriller')
#     Actual Labels: ('Action', 'Crime', 'Thriller')
# Movie 9027:
#     Predicted Labels: ('Romance',)
#     Actual Labels: ('Romance',)
# Movie 9028:
#     Predicted Labels: ('Comedy', 'Drama')
#     Actual Labels: ('Comedy', 'Drama')
# Movie 9029:
#     Predicted Labels: ('Documentary',)
#     Actual Labels: ('Documentary',)
# Movie 9030:
#     Predicted Labels: ('Drama', 'Horror', 'Thriller')
#     Actual Labels: ('Drama', 'Horror', 'Thriller')
# Movie 9031:
#     Predicted Labels: ('Documentary',)
#     Actual Labels: ('Documentary',)
# Movie 9032:
#     Predicted Labels: ('Mystery', 'Thriller')
#     Actual Labels: ('Drama', 'Mystery', 'Thriller')
# Movie 9033:
#     Predicted Labels: ('Action', 'Adventure', 'Drama', 'Thriller')
#     Actual Labels: ('Action', 'Adventure', 'Drama', 'Thriller')
# Movie 9034:
#     Predicted Labels: ('Crime', 'Drama', 'Mystery')
#     Actual Labels: ('Crime', 'Drama', 'Mystery')
# Movie 9035:
#     Predicted Labels: ('Drama', 'Romance', 'Thriller')
#     Actual Labels: ('Drama', 'Romance', 'Thriller')
# Movie 9036:
#     Predicted Labels: ('Mystery',)
#     Actual Labels: ('Drama', 'Mystery')
# Movie 9037:
#     Predicted Labels: ('Documentary',)
#     Actual Labels: ('Documentary',)
# Movie 9038:
#     Predicted Labels: ('Crime', 'Mystery')
#     Actual Labels: ('Crime', 'Mystery')
# Movie 9039:
#     Predicted Labels: ('Drama', 'Horror', 'Thriller')
#     Actual Labels: ('Drama', 'Horror', 'Thriller')
# Movie 9040:
#     Predicted Labels: ('Drama',)
#     Actual Labels: ('Drama',)
# Movie 9041:
#     Predicted Labels: ('Comedy', 'Music')
#     Actual Labels: ('Comedy', 'Music', 'Romance')
# Movie 9042:
#     Predicted Labels: ('Adventure', 'Comedy', 'Family', 'Science Fiction')
#     Actual Labels: ('Adventure', 'Comedy', 'Family', 'Science Fiction')
# Movie 9043:
#     Predicted Labels: ('Drama', 'Fantasy', 'Romance', 'Science Fiction')
#     Actual Labels: ('Drama', 'Fantasy', 'Romance', 'Science Fiction')
# Movie 9044:
#     Predicted Labels: ('Drama',)
#     Actual Labels: ('Drama',)
# Movie 9045:
#     Predicted Labels: ('Action', 'Animation', 'Crime', 'Thriller')
#     Actual Labels: ('Action', 'Animation', 'Crime', 'Thriller')
# Movie 9046:
#     Predicted Labels: ('Crime', 'Mystery')
#     Actual Labels: ('Crime', 'Mystery')
# Movie 9047:
#     Predicted Labels: ('Comedy',)
#     Actual Labels: ('Comedy', 'Drama')
# Movie 9048:
#     Predicted Labels: ('Comedy',)
#     Actual Labels: ()
# Movie 9049:
#     Predicted Labels: ('Action', 'Crime', 'Drama')
#     Actual Labels: ('Action', 'Crime', 'Drama')
# Movie 9050:
#     Predicted Labels: ('Comedy',)
#     Actual Labels: ('Comedy',)
# Movie 9051:
#     Predicted Labels: ('Documentary',)
#     Actual Labels: ('Documentary',)
# Movie 9052:
#     Predicted Labels: ('Comedy',)
#     Actual Labels: ('Comedy',)
# Movie 9053:
#     Predicted Labels: ('Drama', 'Romance')
#     Actual Labels: ('Drama', 'Romance')
# Movie 9054:
#     Predicted Labels: ('Adventure',)
#     Actual Labels: ('Adventure', 'Comedy')
# Movie 9055:
#     Predicted Labels: ('Adventure', 'Drama', 'Fantasy')
#     Actual Labels: ('Adventure', 'Drama', 'Fantasy')
# Movie 9056:
#     Predicted Labels: ('Adventure', 'Horror', 'Science Fiction')
#     Actual Labels: ('Action', 'Adventure', 'Horror', 'Science Fiction')
# Movie 9057:
#     Predicted Labels: ('Documentary',)
#     Actual Labels: ('Documentary',)
# Movie 9058:
#     Predicted Labels: ('Drama', 'Thriller')
#     Actual Labels: ('Drama', 'Thriller')
# Movie 9059:
#     Predicted Labels: ('Drama', 'Family')
#     Actual Labels: ('Drama', 'Family')
# Movie 9060:
#     Predicted Labels: ('Comedy', 'Romance')
#     Actual Labels: ('Comedy', 'Romance')
# Movie 9061:
#     Predicted Labels: ('Action', 'Crime')
#     Actual Labels: ('Action', 'Crime')
# Movie 9062:
#     Predicted Labels: ('Drama',)
#     Actual Labels: ('Drama',)
# Movie 9063:
#     Predicted Labels: ('Horror', 'Mystery', 'Thriller')
#     Actual Labels: ('Horror', 'Mystery', 'Thriller')
# Movie 9064:
#     Predicted Labels: ('Mystery', 'Thriller')
#     Actual Labels: ('Mystery', 'Thriller')
# Movie 9065:
#     Predicted Labels: ('Animation', 'Comedy', 'Music')
#     Actual Labels: ('Animation', 'Comedy', 'Music')
# Movie 9066:
#     Predicted Labels: ('Drama',)
#     Actual Labels: ('Drama',)
# Movie 9067:
#     Predicted Labels: ()
#     Actual Labels: ()
# Movie 9068:
#     Predicted Labels: ('Documentary',)
#     Actual Labels: ('Documentary',)
# Movie 9069:
#     Predicted Labels: ('Drama',)
#     Actual Labels: ('Drama', 'Romance')
# Movie 9070:
#     Predicted Labels: ('Action', 'Comedy', 'Thriller')
#     Actual Labels: ('Action', 'Comedy', 'Thriller')
# Movie 9071:
#     Predicted Labels: ('Drama', 'Thriller')
#     Actual Labels: ('Drama', 'Thriller')
# Movie 9072:
#     Predicted Labels: ('Comedy',)
#     Actual Labels: ('Comedy',)
# Movie 9073:
#     Predicted Labels: ('Action', 'Science Fiction')
#     Actual Labels: ('Action', 'Science Fiction')
# Movie 9074:
#     Predicted Labels: ('Documentary',)
#     Actual Labels: ('Documentary',)
# Movie 9075:
#     Predicted Labels: ('Animation',)
#     Actual Labels: ('Animation',)
# Movie 9076:
#     Predicted Labels: ()
#     Actual Labels: ('Comedy',)
# Movie 9077:
#     Predicted Labels: ('Comedy', 'Romance')
#     Actual Labels: ('Comedy', 'Romance')
# Movie 9078:
#     Predicted Labels: ('Drama',)
#     Actual Labels: ('Drama',)
# Movie 9079:
#     Predicted Labels: ('Drama', 'History', 'War')
#     Actual Labels: ('Drama', 'History', 'War')
# Movie 9080:
#     Predicted Labels: ('Action', 'Drama', 'Thriller')
#     Actual Labels: ('Action', 'Drama', 'Thriller')
# Movie 9081:
#     Predicted Labels: ('Drama', 'History', 'Romance')
#     Actual Labels: ('Drama', 'History', 'Romance')
# Movie 9082:
#     Predicted Labels: ('Documentary',)
#     Actual Labels: ('Documentary',)
# Movie 9083:
#     Predicted Labels: ('Comedy', 'Drama', 'Music', 'Romance')
#     Actual Labels: ('Comedy', 'Drama', 'Music', 'Romance')
# Movie 9084:
#     Predicted Labels: ('Comedy', 'Drama')
#     Actual Labels: ('Comedy', 'Drama')
# Movie 9085:
#     Predicted Labels: ('Drama',)
#     Actual Labels: ('Drama',)
# Movie 9086:
#     Predicted Labels: ('Comedy',)
#     Actual Labels: ('Comedy',)
# Movie 9087:
#     Predicted Labels: ('Comedy', 'Romance')
#     Actual Labels: ('Comedy', 'Romance')
# Movie 9088:
#     Predicted Labels: ('Documentary',)
#     Actual Labels: ('Documentary',)
# Movie 9089:
#     Predicted Labels: ('Animation', 'Family', 'Foreign')
#     Actual Labels: ('Animation', 'Family', 'Foreign')
# Movie 9090:
#     Predicted Labels: ('Drama', 'Thriller')
#     Actual Labels: ('Drama', 'Thriller')
# Movie 9091:
#     Predicted Labels: ('Horror', 'Science Fiction')
#     Actual Labels: ('Horror', 'Science Fiction')
# Movie 9092:
#     Predicted Labels: ('Comedy', 'Family')
#     Actual Labels: ('Comedy',)
# F1-score: 0.9695

# %%
def test_model(movie_descriptions, doc2vec_model, model, mlb):
    tagged_docs = [TaggedDocument(words=word_tokenize(desc.lower()), tags=[str(i)]) for i, desc in enumerate(movie_descriptions)]
    embeddings = [doc2vec_model.infer_vector(doc.words) for doc in tagged_docs]
    X_test_np = np.array(embeddings, dtype=np.float32)
    X_test_tensor = torch.tensor(X_test_np).to(device)

    model.eval()
    with torch.no_grad():
        outputs = model(X_test_tensor)

    # Get top N genres with the highest probabilities
    N = 3  # Number of top genres to select
    top_n_indices = np.argsort(-outputs.cpu().numpy())[:, :3]
    predicted_genres = mlb.classes_[top_n_indices]

    return predicted_genres


# Example movie descriptions to test the model
example_movie_descriptions = [
    "A boy discovers some powers and ready to conquer the world",
    "Ailens comes from the future and destorying the earth",
    "An amazing comedy movie with an unexpected turn of events",
    "A gas station becomes the center of social life in the village after six Swedish girls start working there.",
]

test_model(example_movie_descriptions, doc2vec_model, model, mlb)
# Out:
# array([['Comedy', 'Drama', 'Documentary'],
#        ['Comedy', 'Drama', 'Adventure'],
#        ['Comedy', 'Drama', 'Horror'],
#        ['Drama', 'Comedy', 'War']], dtype=object)

# %% [markdown]
# ### Extracting the `genre_embeddings` to use it for our `movie_recommendation` system
#
# The `genre_embeddings` are taken from the `penultimate` layer of our Neural Network. The pratical way to think about this is based on the fact that if our classification model was able to predict the `genres` for the different movies, it might understood the relevances of the different `movies` which we want for our `movie_recommendation` system
#
# Refer to [blog](https://colab.research.google.com/drive/1B6I5SEXzuuEVaHcy4IwaJlrMy8wJfPSx?usp=sharing) to understand more about it.

# %%
def extract_genre_embeddings(model, X_data):
    model.eval()
    with torch.no_grad():
        embeddings = model.fc3(model.relu(model.fc2(model.relu(model.fc1(X_data.to(device))))))
    return embeddings.cpu().numpy()

train_embeddings = extract_genre_embeddings(model, X_train_tensor)
test_embeddings = extract_genre_embeddings(model, X_test_tensor)

# Combine training and test data
all_indices = valid_indices[:len(X_train_tensor)] + valid_indices[len(X_train_tensor):]
all_embeddings = np.concatenate((train_embeddings, test_embeddings), axis=0)
all_genres = np.concatenate((y_train_np, y_test_np), axis=0)

# Create a dataframe
movie_embeddings_df = pd.DataFrame({
    'movie_index': all_indices,
    'title': [movie_data.loc[idx, 'title'] for idx in all_indices],
    'genre_embeddings': [list(embeddings) for embeddings in all_embeddings],  # Convert each array of embeddings to a list
    'genre_labels': [mlb.classes_[labels.nonzero()[0]] for labels in all_genres]
})

# Save the data as a csv file
movie_embeddings_df.to_csv("movie_embeddings.csv", index=False)

# %% [markdown]
# ### Storing the `genre_embeddings` to `LanceDB` Vector Database

# %%
import ast
import lancedb
import pandas as pd
from lancedb.pydantic import LanceModel, Vector

data = pd.read_csv("movie_embeddings.csv")
data.drop(columns=["movie_index"], inplace=True)

movie_data = []
for index, row in data.iterrows():
    embedding_vector = ast.literal_eval(row["genre_embeddings"])
    movie_data.append(
        {
            "title": row['title'],
            "embeddings": embedding_vector,
            "genre_labels": row['genre_labels']
        }
    )

# Define LanceDB model
class Movie(LanceModel):
    title: str
    embeddings: Vector(128)
    genre_labels: str

# Create LanceDB connection
db = lancedb.connect("./db")
movie_table = db.create_table(
    "movies",
    schema=Movie,
    mode="Overwrite")
movie_table.add(movie_data)

# %% [markdown]
# ### Prediction based on the `genre_embeddings`

# %%
movie_data_pd = pd.DataFrame(movie_data)
def get_recommendation(title):
    result = (
        movie_table.search(movie_data_pd[movie_data_pd["title"] == title]["embeddings"].values[0]).metric('cosine')
        .limit(5)
        .to_pandas()
    )
    return result

result = get_recommendation("Toy Story")
result[['title']]
# Out:
#                           title
# 0                     Toy Story
# 1  Blood Sisters of Lesbian Sin
# 2            Hostile Intentions
# 3                     Satyricon
# 4                    Underworld

# %% [markdown]
# ### Note: The current implementation of the Neural Network is quite basic and serves primarily for the demonstration. While the movie recommendations generated are relatively simple and may be wrong, they can be significantly improved by using a more sophisticated and larger Neural Network within the same workflow.
